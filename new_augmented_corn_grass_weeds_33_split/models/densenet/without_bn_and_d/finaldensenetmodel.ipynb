# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 50
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = DenseNet121(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=output)


optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 8,781,675
# Trainable parameters: 8,698,027

# %%
checkpoint_cb = ModelCheckpoint(
    "best_densenet_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "Densenet Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Densenet Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"TREUnpICaDEs","time":1755960617,"expires":1756003817,"event":"message","topic":"model_complete","message":"Densenet Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755960712.772694      75 service.cc:148] XLA service 0x7f5b380025c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755960712.773546      75 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755960721.685875      75 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1755960800.920601      75 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.2257 - loss: 2.5748
# Epoch 1: val_accuracy improved from -inf to 0.27570, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 454s 612ms/step - accuracy: 0.2260 - loss: 2.5736 - val_accuracy: 0.2757 - val_loss: 3.4232 - learning_rate: 0.0010
# Epoch 2/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5394 - loss: 1.2690
# Epoch 2: val_accuracy improved from 0.27570 to 0.36922, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 261ms/step - accuracy: 0.5396 - loss: 1.2687 - val_accuracy: 0.3692 - val_loss: 2.2791 - learning_rate: 0.0010
# Epoch 3/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7140 - loss: 0.7966
# Epoch 3: val_accuracy improved from 0.36922 to 0.69201, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 257ms/step - accuracy: 0.7140 - loss: 0.7965 - val_accuracy: 0.6920 - val_loss: 0.8862 - learning_rate: 0.0010
# Epoch 4/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7671 - loss: 0.6321
# Epoch 4: val_accuracy did not improve from 0.69201
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.7671 - loss: 0.6321 - val_accuracy: 0.6836 - val_loss: 0.9923 - learning_rate: 0.0010
# Epoch 5/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8193 - loss: 0.5041
# Epoch 5: val_accuracy improved from 0.69201 to 0.73802, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 261ms/step - accuracy: 0.8193 - loss: 0.5041 - val_accuracy: 0.7380 - val_loss: 0.7372 - learning_rate: 0.0010
# Epoch 6/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8497 - loss: 0.4157
# Epoch 6: val_accuracy did not improve from 0.73802
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 258ms/step - accuracy: 0.8497 - loss: 0.4157 - val_accuracy: 0.7270 - val_loss: 0.8792 - learning_rate: 0.0010
# Epoch 7/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8678 - loss: 0.3687
# Epoch 7: val_accuracy did not improve from 0.73802
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 257ms/step - accuracy: 0.8678 - loss: 0.3688 - val_accuracy: 0.6079 - val_loss: 1.6091 - learning_rate: 0.0010
# Epoch 8/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8770 - loss: 0.3450
# Epoch 8: val_accuracy improved from 0.73802 to 0.82677, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 257ms/step - accuracy: 0.8770 - loss: 0.3450 - val_accuracy: 0.8268 - val_loss: 0.5018 - learning_rate: 0.0010
# Epoch 9/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8909 - loss: 0.3064
# Epoch 9: val_accuracy did not improve from 0.82677
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 263ms/step - accuracy: 0.8909 - loss: 0.3064 - val_accuracy: 0.7560 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 10/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9020 - loss: 0.2865
# Epoch 10: val_accuracy did not improve from 0.82677
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 257ms/step - accuracy: 0.9019 - loss: 0.2865 - val_accuracy: 0.7910 - val_loss: 0.5887 - learning_rate: 0.0010
# Epoch 11/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9065 - loss: 0.2807
# Epoch 11: val_accuracy did not improve from 0.82677
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 260ms/step - accuracy: 0.9065 - loss: 0.2807 - val_accuracy: 0.7674 - val_loss: 0.7274 - learning_rate: 0.0010
# Epoch 12/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9235 - loss: 0.2308
# Epoch 12: val_accuracy did not improve from 0.82677
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 259ms/step - accuracy: 0.9235 - loss: 0.2309 - val_accuracy: 0.8157 - val_loss: 0.5794 - learning_rate: 0.0010
# Epoch 13/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9207 - loss: 0.2260
# Epoch 13: val_accuracy did not improve from 0.82677
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.9207 - loss: 0.2260 - val_accuracy: 0.8038 - val_loss: 0.6073 - learning_rate: 0.0010
# Epoch 14/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9626 - loss: 0.1105
# Epoch 14: val_accuracy improved from 0.82677 to 0.90355, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 255ms/step - accuracy: 0.9626 - loss: 0.1104 - val_accuracy: 0.9036 - val_loss: 0.2804 - learning_rate: 5.0000e-04
# Epoch 15/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9745 - loss: 0.0781
# Epoch 15: val_accuracy did not improve from 0.90355
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9745 - loss: 0.0781 - val_accuracy: 0.8871 - val_loss: 0.3567 - learning_rate: 5.0000e-04
# Epoch 16/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9735 - loss: 0.0763
# Epoch 16: val_accuracy improved from 0.90355 to 0.92304, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 256ms/step - accuracy: 0.9735 - loss: 0.0763 - val_accuracy: 0.9230 - val_loss: 0.2538 - learning_rate: 5.0000e-04
# Epoch 17/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9741 - loss: 0.0744
# Epoch 17: val_accuracy did not improve from 0.92304
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9741 - loss: 0.0744 - val_accuracy: 0.9203 - val_loss: 0.2619 - learning_rate: 5.0000e-04
# Epoch 18/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9774 - loss: 0.0700
# Epoch 18: val_accuracy did not improve from 0.92304
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9774 - loss: 0.0700 - val_accuracy: 0.8815 - val_loss: 0.4309 - learning_rate: 5.0000e-04
# Epoch 19/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9783 - loss: 0.0678
# Epoch 19: val_accuracy improved from 0.92304 to 0.92405, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 253ms/step - accuracy: 0.9783 - loss: 0.0678 - val_accuracy: 0.9240 - val_loss: 0.2752 - learning_rate: 5.0000e-04
# Epoch 20/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9729 - loss: 0.0816
# Epoch 20: val_accuracy did not improve from 0.92405
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9729 - loss: 0.0816 - val_accuracy: 0.9179 - val_loss: 0.2971 - learning_rate: 5.0000e-04
# Epoch 21/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9770 - loss: 0.0735
# Epoch 21: val_accuracy did not improve from 0.92405
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 248ms/step - accuracy: 0.9770 - loss: 0.0736 - val_accuracy: 0.9104 - val_loss: 0.3013 - learning_rate: 5.0000e-04
# Epoch 22/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9874 - loss: 0.0399
# Epoch 22: val_accuracy improved from 0.92405 to 0.94053, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9874 - loss: 0.0399 - val_accuracy: 0.9405 - val_loss: 0.2266 - learning_rate: 2.5000e-04
# Epoch 23/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9959 - loss: 0.0155
# Epoch 23: val_accuracy improved from 0.94053 to 0.94496, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 256ms/step - accuracy: 0.9959 - loss: 0.0155 - val_accuracy: 0.9450 - val_loss: 0.2192 - learning_rate: 2.5000e-04
# Epoch 24/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9983 - loss: 0.0079
# Epoch 24: val_accuracy did not improve from 0.94496
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9983 - loss: 0.0079 - val_accuracy: 0.9282 - val_loss: 0.3004 - learning_rate: 2.5000e-04
# Epoch 25/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9940 - loss: 0.0241
# Epoch 25: val_accuracy did not improve from 0.94496
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9940 - loss: 0.0241 - val_accuracy: 0.9317 - val_loss: 0.2744 - learning_rate: 2.5000e-04
# Epoch 26/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9920 - loss: 0.0269
# Epoch 26: val_accuracy did not improve from 0.94496
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9920 - loss: 0.0269 - val_accuracy: 0.9384 - val_loss: 0.2592 - learning_rate: 2.5000e-04
# Epoch 27/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9928 - loss: 0.0225
# Epoch 27: val_accuracy improved from 0.94496 to 0.94906, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 255ms/step - accuracy: 0.9928 - loss: 0.0225 - val_accuracy: 0.9491 - val_loss: 0.1924 - learning_rate: 2.5000e-04
# Epoch 28/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9949 - loss: 0.0183
# Epoch 28: val_accuracy did not improve from 0.94906
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 253ms/step - accuracy: 0.9949 - loss: 0.0183 - val_accuracy: 0.9286 - val_loss: 0.3089 - learning_rate: 2.5000e-04
# Epoch 29/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9939 - loss: 0.0197
# Epoch 29: val_accuracy did not improve from 0.94906
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 248ms/step - accuracy: 0.9939 - loss: 0.0197 - val_accuracy: 0.9344 - val_loss: 0.2646 - learning_rate: 2.5000e-04
# Epoch 30/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9941 - loss: 0.0218
# Epoch 30: val_accuracy did not improve from 0.94906
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9941 - loss: 0.0218 - val_accuracy: 0.9428 - val_loss: 0.2339 - learning_rate: 2.5000e-04
# Epoch 31/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9958 - loss: 0.0126
# Epoch 31: val_accuracy did not improve from 0.94906
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9958 - loss: 0.0126 - val_accuracy: 0.9384 - val_loss: 0.2382 - learning_rate: 2.5000e-04
# Epoch 32/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9954 - loss: 0.0136
# Epoch 32: val_accuracy did not improve from 0.94906
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9954 - loss: 0.0136 - val_accuracy: 0.9457 - val_loss: 0.2296 - learning_rate: 2.5000e-04
# Epoch 33/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9982 - loss: 0.0057
# Epoch 33: val_accuracy did not improve from 0.94906
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9491 - val_loss: 0.2215 - learning_rate: 1.2500e-04
# Epoch 34/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9974 - loss: 0.0094
# Epoch 34: val_accuracy improved from 0.94906 to 0.95316, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.9532 - val_loss: 0.2025 - learning_rate: 1.2500e-04
# Epoch 35/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9994 - loss: 0.0025
# Epoch 35: val_accuracy improved from 0.95316 to 0.95801, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 257ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.9580 - val_loss: 0.1918 - learning_rate: 1.2500e-04
# Epoch 36/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9994 - loss: 0.0022
# Epoch 36: val_accuracy did not improve from 0.95801
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 247ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9568 - val_loss: 0.1955 - learning_rate: 1.2500e-04
# Epoch 37/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9967 - loss: 0.0141
# Epoch 37: val_accuracy did not improve from 0.95801
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9967 - loss: 0.0141 - val_accuracy: 0.9499 - val_loss: 0.2388 - learning_rate: 1.2500e-04
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
# Training completed!
# {"id":"80Cg0uUCbvIk","time":1755965144,"expires":1756008344,"event":"message","topic":"model_complete","message":"Densenet Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 118s 282ms/step
# Test Loss: 0.2157
# Test Accuracy: 0.9457
# Precision: 0.9160
# Recall: 0.9192
# F1 Score: 0.9164
# Parameters: 8781675

# %%
model.save('densenet_final_model.keras')
model.save_weights('densenet_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["DenseNet121"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()
# Out:
# | Model       |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | DenseNet121 |  8781675 |      0.2157 |     0.9457 |       0.916 |   0.9192 | 0.9164 |
