# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 50
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = DenseNet121(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=output)


optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 8,788,843
# Trainable parameters: 8,701,611

# %%
checkpoint_cb = ModelCheckpoint(
    "best_densenet_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"p4OVQqX8wsN3","time":1755024628,"expires":1755067828,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755024726.629200      74 service.cc:148] XLA service 0x7a9de40023b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755024726.630107      74 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755024735.896623      74 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1755024822.795052      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.1397 - loss: 3.1790
# Epoch 1: val_accuracy improved from -inf to 0.30974, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 528s 751ms/step - accuracy: 0.1399 - loss: 3.1775 - val_accuracy: 0.3097 - val_loss: 2.2060 - learning_rate: 0.0010
# Epoch 2/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4550 - loss: 1.5382
# Epoch 2: val_accuracy improved from 0.30974 to 0.52171, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 270ms/step - accuracy: 0.4551 - loss: 1.5378 - val_accuracy: 0.5217 - val_loss: 1.3984 - learning_rate: 0.0010
# Epoch 3/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6092 - loss: 1.0604
# Epoch 3: val_accuracy did not improve from 0.52171
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 122s 275ms/step - accuracy: 0.6092 - loss: 1.0603 - val_accuracy: 0.4176 - val_loss: 1.9410 - learning_rate: 0.0010
# Epoch 4/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7017 - loss: 0.8128
# Epoch 4: val_accuracy did not improve from 0.52171
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 266ms/step - accuracy: 0.7017 - loss: 0.8128 - val_accuracy: 0.4708 - val_loss: 1.6362 - learning_rate: 0.0010
# Epoch 5/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7551 - loss: 0.6777
# Epoch 5: val_accuracy improved from 0.52171 to 0.63246, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 122s 274ms/step - accuracy: 0.7551 - loss: 0.6777 - val_accuracy: 0.6325 - val_loss: 1.1501 - learning_rate: 0.0010
# Epoch 6/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7825 - loss: 0.5879
# Epoch 6: val_accuracy improved from 0.63246 to 0.77942, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.7825 - loss: 0.5879 - val_accuracy: 0.7794 - val_loss: 0.5904 - learning_rate: 0.0010
# Epoch 7/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8145 - loss: 0.5157
# Epoch 7: val_accuracy did not improve from 0.77942
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 266ms/step - accuracy: 0.8145 - loss: 0.5157 - val_accuracy: 0.7484 - val_loss: 0.7384 - learning_rate: 0.0010
# Epoch 8/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8203 - loss: 0.4987
# Epoch 8: val_accuracy did not improve from 0.77942
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 271ms/step - accuracy: 0.8203 - loss: 0.4987 - val_accuracy: 0.7378 - val_loss: 0.7440 - learning_rate: 0.0010
# Epoch 9/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8477 - loss: 0.4288
# Epoch 9: val_accuracy did not improve from 0.77942
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.8477 - loss: 0.4288 - val_accuracy: 0.7372 - val_loss: 0.7857 - learning_rate: 0.0010
# Epoch 10/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8432 - loss: 0.4299
# Epoch 10: val_accuracy did not improve from 0.77942
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 270ms/step - accuracy: 0.8432 - loss: 0.4299 - val_accuracy: 0.6668 - val_loss: 1.1121 - learning_rate: 0.0010
# Epoch 11/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8632 - loss: 0.3765
# Epoch 11: val_accuracy did not improve from 0.77942
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 121s 271ms/step - accuracy: 0.8632 - loss: 0.3765 - val_accuracy: 0.7224 - val_loss: 0.9169 - learning_rate: 0.0010
# Epoch 12/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9128 - loss: 0.2406
# Epoch 12: val_accuracy improved from 0.77942 to 0.88833, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 268ms/step - accuracy: 0.9128 - loss: 0.2405 - val_accuracy: 0.8883 - val_loss: 0.3268 - learning_rate: 5.0000e-04
# Epoch 13/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9526 - loss: 0.1438
# Epoch 13: val_accuracy did not improve from 0.88833
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.9526 - loss: 0.1438 - val_accuracy: 0.8857 - val_loss: 0.3431 - learning_rate: 5.0000e-04
# Epoch 14/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9430 - loss: 0.1638
# Epoch 14: val_accuracy did not improve from 0.88833
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 264ms/step - accuracy: 0.9430 - loss: 0.1638 - val_accuracy: 0.8770 - val_loss: 0.3646 - learning_rate: 5.0000e-04
# Epoch 15/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9420 - loss: 0.1737
# Epoch 15: val_accuracy did not improve from 0.88833
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 268ms/step - accuracy: 0.9420 - loss: 0.1738 - val_accuracy: 0.8765 - val_loss: 0.3837 - learning_rate: 5.0000e-04
# Epoch 16/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9465 - loss: 0.1569
# Epoch 16: val_accuracy improved from 0.88833 to 0.91635, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 267ms/step - accuracy: 0.9465 - loss: 0.1569 - val_accuracy: 0.9164 - val_loss: 0.2495 - learning_rate: 5.0000e-04
# Epoch 17/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9556 - loss: 0.1311
# Epoch 17: val_accuracy did not improve from 0.91635
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 262ms/step - accuracy: 0.9555 - loss: 0.1311 - val_accuracy: 0.8693 - val_loss: 0.4225 - learning_rate: 5.0000e-04
# Epoch 18/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9571 - loss: 0.1340
# Epoch 18: val_accuracy did not improve from 0.91635
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 121s 272ms/step - accuracy: 0.9571 - loss: 0.1340 - val_accuracy: 0.8980 - val_loss: 0.3357 - learning_rate: 5.0000e-04
# Epoch 19/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9528 - loss: 0.1359
# Epoch 19: val_accuracy did not improve from 0.91635
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 265ms/step - accuracy: 0.9528 - loss: 0.1359 - val_accuracy: 0.8877 - val_loss: 0.3951 - learning_rate: 5.0000e-04
# Epoch 20/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9533 - loss: 0.1380
# Epoch 20: val_accuracy did not improve from 0.91635
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 266ms/step - accuracy: 0.9533 - loss: 0.1380 - val_accuracy: 0.8981 - val_loss: 0.3498 - learning_rate: 5.0000e-04
# Epoch 21/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9621 - loss: 0.1176
# Epoch 21: val_accuracy did not improve from 0.91635
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 267ms/step - accuracy: 0.9621 - loss: 0.1176 - val_accuracy: 0.8857 - val_loss: 0.4004 - learning_rate: 5.0000e-04
# Epoch 22/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9793 - loss: 0.0681
# Epoch 22: val_accuracy improved from 0.91635 to 0.93568, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 267ms/step - accuracy: 0.9793 - loss: 0.0681 - val_accuracy: 0.9357 - val_loss: 0.2184 - learning_rate: 2.5000e-04
# Epoch 23/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9885 - loss: 0.0394
# Epoch 23: val_accuracy improved from 0.93568 to 0.94529, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 122s 273ms/step - accuracy: 0.9885 - loss: 0.0394 - val_accuracy: 0.9453 - val_loss: 0.1989 - learning_rate: 2.5000e-04
# Epoch 24/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9897 - loss: 0.0343
# Epoch 24: val_accuracy did not improve from 0.94529
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 263ms/step - accuracy: 0.9897 - loss: 0.0344 - val_accuracy: 0.9296 - val_loss: 0.2539 - learning_rate: 2.5000e-04
# Epoch 25/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9884 - loss: 0.0397
# Epoch 25: val_accuracy did not improve from 0.94529
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.9884 - loss: 0.0397 - val_accuracy: 0.9332 - val_loss: 0.2491 - learning_rate: 2.5000e-04
# Epoch 26/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9890 - loss: 0.0333
# Epoch 26: val_accuracy did not improve from 0.94529
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 263ms/step - accuracy: 0.9890 - loss: 0.0333 - val_accuracy: 0.9396 - val_loss: 0.2355 - learning_rate: 2.5000e-04
# Epoch 27/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9856 - loss: 0.0462
# Epoch 27: val_accuracy did not improve from 0.94529
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 264ms/step - accuracy: 0.9856 - loss: 0.0462 - val_accuracy: 0.9276 - val_loss: 0.2943 - learning_rate: 2.5000e-04
# Epoch 28/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9880 - loss: 0.0372
# Epoch 28: val_accuracy did not improve from 0.94529
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 264ms/step - accuracy: 0.9880 - loss: 0.0372 - val_accuracy: 0.9309 - val_loss: 0.2833 - learning_rate: 2.5000e-04
# Epoch 29/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9897 - loss: 0.0328
# Epoch 29: val_accuracy improved from 0.94529 to 0.95291, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.9897 - loss: 0.0328 - val_accuracy: 0.9529 - val_loss: 0.1913 - learning_rate: 1.2500e-04
# Epoch 30/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9969 - loss: 0.0131
# Epoch 30: val_accuracy improved from 0.95291 to 0.95475, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 122s 274ms/step - accuracy: 0.9969 - loss: 0.0131 - val_accuracy: 0.9547 - val_loss: 0.1838 - learning_rate: 1.2500e-04
# Epoch 31/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9955 - loss: 0.0144
# Epoch 31: val_accuracy did not improve from 0.95475
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 117s 264ms/step - accuracy: 0.9955 - loss: 0.0144 - val_accuracy: 0.9543 - val_loss: 0.1937 - learning_rate: 1.2500e-04
# Epoch 32/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9943 - loss: 0.0171
# Epoch 32: val_accuracy improved from 0.95475 to 0.95491, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 269ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.9549 - val_loss: 0.1993 - learning_rate: 1.2500e-04
# Epoch 33/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9968 - loss: 0.0102
# Epoch 33: val_accuracy did not improve from 0.95491
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 121s 271ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 0.9496 - val_loss: 0.2238 - learning_rate: 1.2500e-04
# Epoch 34/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9952 - loss: 0.0136
# Epoch 34: val_accuracy did not improve from 0.95491
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 265ms/step - accuracy: 0.9952 - loss: 0.0136 - val_accuracy: 0.9512 - val_loss: 0.2047 - learning_rate: 1.2500e-04
# Epoch 35/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9976 - loss: 0.0100
# Epoch 35: val_accuracy did not improve from 0.95491
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 264ms/step - accuracy: 0.9976 - loss: 0.0100 - val_accuracy: 0.9476 - val_loss: 0.2309 - learning_rate: 1.2500e-04
# Epoch 36/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9981 - loss: 0.0068
# Epoch 36: val_accuracy improved from 0.95491 to 0.95517, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 125s 280ms/step - accuracy: 0.9981 - loss: 0.0068 - val_accuracy: 0.9552 - val_loss: 0.2015 - learning_rate: 6.2500e-05
# Epoch 37/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9985 - loss: 0.0067
# Epoch 37: val_accuracy did not improve from 0.95517
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 124s 279ms/step - accuracy: 0.9985 - loss: 0.0067 - val_accuracy: 0.9552 - val_loss: 0.2042 - learning_rate: 6.2500e-05
# Epoch 38/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9991 - loss: 0.0053
# Epoch 38: val_accuracy did not improve from 0.95517
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 264ms/step - accuracy: 0.9991 - loss: 0.0053 - val_accuracy: 0.9536 - val_loss: 0.2113 - learning_rate: 6.2500e-05
# Epoch 39/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 39: val_accuracy improved from 0.95517 to 0.95567, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 267ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9557 - val_loss: 0.2068 - learning_rate: 6.2500e-05
# Epoch 40/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9991 - loss: 0.0050
# Epoch 40: val_accuracy improved from 0.95567 to 0.95734, saving model to best_densenet_model.h5
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 120s 270ms/step - accuracy: 0.9991 - loss: 0.0050 - val_accuracy: 0.9573 - val_loss: 0.2055 - learning_rate: 6.2500e-05
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Training completed!
# {"id":"iYk0U0Q5kv6c","time":1755029819,"expires":1755073019,"event":"message","topic":"model_complete","message":"Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step
# Test Loss: 0.1966
# Test Accuracy: 0.9489
# Precision: 0.9220
# Recall: 0.9280
# F1 Score: 0.9235
# Parameters: 8788843

# %%
model.save('densenet_final_model.keras')
model.save_weights('densenet_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["DenseNet121"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# !curl -d "Finished" ntfy.sh/model_complete
# Out:
# | Model       |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | DenseNet121 |  8788843 |      0.1966 |     0.9489 |       0.922 |    0.928 | 0.9235 |
# {"id":"GBknmg9ASi4I","time":1755030131,"expires":1755073331,"event":"message","topic":"model_complete","message":"Finished"}
