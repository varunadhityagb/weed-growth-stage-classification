# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ConvNeXtTiny
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.2
INITIAL_LR = 1e-5
EPOCHS = 50
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = ConvNeXtTiny(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=output)

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_flow.classes),
    y=train_flow.classes
)
class_weight_dict = dict(enumerate(class_weights))

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 29,309,323
# Trainable parameters: 29,305,739

# %%
checkpoint_cb = ModelCheckpoint(
    "best_ConvNeXtTiny_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=7, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "convnexttiny Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)

print("Training completed!")
# !curl -d "convnexttiny Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"sTppZyw1D9dQ","time":1755358500,"expires":1755401700,"event":"message","topic":"model_complete","message":"convnexttiny Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755358546.825679     116 service.cc:148] XLA service 0x7cd06009a110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755358546.826489     116 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755358551.158794     116 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1755358555.650007     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358555.826541     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358556.070421     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358556.265429     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1755358571.799478     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 113/445 ━━━━━━━━━━━━━━━━━━━━ 1:56 349ms/step - accuracy: 0.0356 - loss: 4.3153
# E0000 00:00:1755358617.621786     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358617.797743     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358618.036738     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755358618.231371     117 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.0339 - loss: 4.2449
# Epoch 1: val_accuracy improved from -inf to 0.07863, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 355s 640ms/step - accuracy: 0.0339 - loss: 4.2447 - val_accuracy: 0.0786 - val_loss: 3.6390 - learning_rate: 1.0000e-05
# Epoch 2/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.0683 - loss: 3.7654
# Epoch 2: val_accuracy improved from 0.07863 to 0.10857, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 450ms/step - accuracy: 0.0684 - loss: 3.7652 - val_accuracy: 0.1086 - val_loss: 3.4077 - learning_rate: 1.0000e-05
# Epoch 3/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.1238 - loss: 3.3632
# Epoch 3: val_accuracy improved from 0.10857 to 0.15274, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 203s 455ms/step - accuracy: 0.1238 - loss: 3.3630 - val_accuracy: 0.1527 - val_loss: 3.2168 - learning_rate: 1.0000e-05
# Epoch 4/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.1626 - loss: 3.0802
# Epoch 4: val_accuracy improved from 0.15274 to 0.18168, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 452ms/step - accuracy: 0.1626 - loss: 3.0800 - val_accuracy: 0.1817 - val_loss: 3.0160 - learning_rate: 1.0000e-05
# Epoch 5/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.2006 - loss: 2.8252
# Epoch 5: val_accuracy improved from 0.18168 to 0.21363, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 447ms/step - accuracy: 0.2006 - loss: 2.8251 - val_accuracy: 0.2136 - val_loss: 2.8183 - learning_rate: 1.0000e-05
# Epoch 6/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.2401 - loss: 2.5704
# Epoch 6: val_accuracy improved from 0.21363 to 0.26801, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 203s 457ms/step - accuracy: 0.2401 - loss: 2.5703 - val_accuracy: 0.2680 - val_loss: 2.5821 - learning_rate: 1.0000e-05
# Epoch 7/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.3217 - loss: 2.1152
# Epoch 8: val_accuracy improved from 0.29879 to 0.33802, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 212s 476ms/step - accuracy: 0.3217 - loss: 2.1151 - val_accuracy: 0.3380 - val_loss: 2.2184 - learning_rate: 1.0000e-05
# Epoch 9/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.3774 - loss: 1.9327
# Epoch 9: val_accuracy improved from 0.33802 to 0.39164, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 198s 444ms/step - accuracy: 0.3774 - loss: 1.9326 - val_accuracy: 0.3916 - val_loss: 2.0247 - learning_rate: 1.0000e-05
# Epoch 10/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4290 - loss: 1.7266
# Epoch 10: val_accuracy improved from 0.39164 to 0.41506, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.4290 - loss: 1.7265 - val_accuracy: 0.4151 - val_loss: 1.8583 - learning_rate: 1.0000e-05
# Epoch 11/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.4560 - loss: 1.5774
# Epoch 11: val_accuracy improved from 0.41506 to 0.46658, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 196s 441ms/step - accuracy: 0.4560 - loss: 1.5773 - val_accuracy: 0.4666 - val_loss: 1.6787 - learning_rate: 1.0000e-05
# Epoch 12/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5016 - loss: 1.4241
# Epoch 12: val_accuracy improved from 0.46658 to 0.48365, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 449ms/step - accuracy: 0.5016 - loss: 1.4241 - val_accuracy: 0.4836 - val_loss: 1.5631 - learning_rate: 1.0000e-05
# Epoch 13/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5284 - loss: 1.2950
# Epoch 13: val_accuracy improved from 0.48365 to 0.52238, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 449ms/step - accuracy: 0.5284 - loss: 1.2949 - val_accuracy: 0.5224 - val_loss: 1.4233 - learning_rate: 1.0000e-05
# Epoch 14/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5669 - loss: 1.1777
# Epoch 14: val_accuracy improved from 0.52238 to 0.57415, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 446ms/step - accuracy: 0.5669 - loss: 1.1776 - val_accuracy: 0.5742 - val_loss: 1.2875 - learning_rate: 1.0000e-05
# Epoch 15/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.6081 - loss: 1.0585
# Epoch 15: val_accuracy improved from 0.57415 to 0.61330, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 203s 457ms/step - accuracy: 0.6081 - loss: 1.0584 - val_accuracy: 0.6133 - val_loss: 1.1604 - learning_rate: 1.0000e-05
# Epoch 16/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.6440 - loss: 0.9549
# Epoch 16: val_accuracy improved from 0.61330 to 0.64852, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 204s 457ms/step - accuracy: 0.6440 - loss: 0.9548 - val_accuracy: 0.6485 - val_loss: 1.0337 - learning_rate: 1.0000e-05
# Epoch 17/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.6762 - loss: 0.8567
# Epoch 17: val_accuracy improved from 0.64852 to 0.67779, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 452ms/step - accuracy: 0.6762 - loss: 0.8567 - val_accuracy: 0.6778 - val_loss: 0.9734 - learning_rate: 1.0000e-05
# Epoch 18/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7023 - loss: 0.7848
# Epoch 18: val_accuracy improved from 0.67779 to 0.68942, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 206s 462ms/step - accuracy: 0.7023 - loss: 0.7848 - val_accuracy: 0.6894 - val_loss: 0.9075 - learning_rate: 1.0000e-05
# Epoch 19/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7256 - loss: 0.7117
# Epoch 19: val_accuracy improved from 0.68942 to 0.73626, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 206s 464ms/step - accuracy: 0.7256 - loss: 0.7116 - val_accuracy: 0.7363 - val_loss: 0.7842 - learning_rate: 1.0000e-05
# Epoch 20/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7617 - loss: 0.6355
# Epoch 20: val_accuracy improved from 0.73626 to 0.74956, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 202s 454ms/step - accuracy: 0.7617 - loss: 0.6355 - val_accuracy: 0.7496 - val_loss: 0.7293 - learning_rate: 1.0000e-05
# Epoch 21/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7789 - loss: 0.5831
# Epoch 21: val_accuracy improved from 0.74956 to 0.77591, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 203s 456ms/step - accuracy: 0.7789 - loss: 0.5831 - val_accuracy: 0.7759 - val_loss: 0.6699 - learning_rate: 1.0000e-05
# Epoch 22/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8047 - loss: 0.5271
# Epoch 22: val_accuracy improved from 0.77591 to 0.78344, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 203s 457ms/step - accuracy: 0.8047 - loss: 0.5271 - val_accuracy: 0.7834 - val_loss: 0.6431 - learning_rate: 1.0000e-05
# Epoch 23/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8253 - loss: 0.4807
# Epoch 23: val_accuracy improved from 0.78344 to 0.80895, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 205s 461ms/step - accuracy: 0.8253 - loss: 0.4806 - val_accuracy: 0.8090 - val_loss: 0.5642 - learning_rate: 1.0000e-05
# Epoch 24/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8362 - loss: 0.4301
# Epoch 24: val_accuracy did not improve from 0.80895
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 451ms/step - accuracy: 0.8362 - loss: 0.4301 - val_accuracy: 0.7721 - val_loss: 0.6746 - learning_rate: 1.0000e-05
# Epoch 25/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.8536 - loss: 0.4005
# Epoch 25: val_accuracy improved from 0.80895 to 0.82074, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 451ms/step - accuracy: 0.8536 - loss: 0.4004 - val_accuracy: 0.8207 - val_loss: 0.5165 - learning_rate: 1.0000e-05
# Epoch 26/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8772 - loss: 0.3540
# Epoch 26: val_accuracy improved from 0.82074 to 0.83756, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 453ms/step - accuracy: 0.8772 - loss: 0.3539 - val_accuracy: 0.8376 - val_loss: 0.4688 - learning_rate: 1.0000e-05
# Epoch 27/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8907 - loss: 0.2978
# Epoch 27: val_accuracy improved from 0.83756 to 0.84023, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 447ms/step - accuracy: 0.8907 - loss: 0.2979 - val_accuracy: 0.8402 - val_loss: 0.4639 - learning_rate: 1.0000e-05
# Epoch 28/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9047 - loss: 0.2729
# Epoch 28: val_accuracy improved from 0.84023 to 0.84910, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 452ms/step - accuracy: 0.9047 - loss: 0.2729 - val_accuracy: 0.8491 - val_loss: 0.4364 - learning_rate: 1.0000e-05
# Epoch 29/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9088 - loss: 0.2519
# Epoch 29: val_accuracy improved from 0.84910 to 0.85864, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 447ms/step - accuracy: 0.9088 - loss: 0.2519 - val_accuracy: 0.8586 - val_loss: 0.4076 - learning_rate: 1.0000e-05
# Epoch 30/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9252 - loss: 0.2144
# Epoch 30: val_accuracy improved from 0.85864 to 0.86658, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 446ms/step - accuracy: 0.9252 - loss: 0.2145 - val_accuracy: 0.8666 - val_loss: 0.3970 - learning_rate: 1.0000e-05
# Epoch 31/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9278 - loss: 0.2140
# Epoch 31: val_accuracy improved from 0.86658 to 0.87077, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9278 - loss: 0.2140 - val_accuracy: 0.8708 - val_loss: 0.3771 - learning_rate: 1.0000e-05
# Epoch 32/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9411 - loss: 0.1773
# Epoch 32: val_accuracy did not improve from 0.87077
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9411 - loss: 0.1774 - val_accuracy: 0.8645 - val_loss: 0.3992 - learning_rate: 1.0000e-05
# Epoch 33/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9434 - loss: 0.1673
# Epoch 33: val_accuracy did not improve from 0.87077
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 213s 479ms/step - accuracy: 0.9434 - loss: 0.1673 - val_accuracy: 0.8533 - val_loss: 0.4384 - learning_rate: 1.0000e-05
# Epoch 34/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9548 - loss: 0.1397
# Epoch 34: val_accuracy did not improve from 0.87077
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9548 - loss: 0.1397 - val_accuracy: 0.8677 - val_loss: 0.3891 - learning_rate: 1.0000e-05
# Epoch 35/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9630 - loss: 0.1232
# Epoch 35: val_accuracy improved from 0.87077 to 0.88975, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 443ms/step - accuracy: 0.9630 - loss: 0.1232 - val_accuracy: 0.8898 - val_loss: 0.3265 - learning_rate: 5.0000e-06
# Epoch 36/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9694 - loss: 0.1089
# Epoch 36: val_accuracy improved from 0.88975 to 0.89293, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9694 - loss: 0.1089 - val_accuracy: 0.8929 - val_loss: 0.3212 - learning_rate: 5.0000e-06
# Epoch 37/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9707 - loss: 0.0994
# Epoch 37: val_accuracy did not improve from 0.89293
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 441ms/step - accuracy: 0.9707 - loss: 0.0994 - val_accuracy: 0.8886 - val_loss: 0.3369 - learning_rate: 5.0000e-06
# Epoch 38/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9734 - loss: 0.0942
# Epoch 38: val_accuracy did not improve from 0.89293
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 218s 489ms/step - accuracy: 0.9733 - loss: 0.0942 - val_accuracy: 0.8902 - val_loss: 0.3350 - learning_rate: 5.0000e-06
# Epoch 39/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9724 - loss: 0.0904
# Epoch 39: val_accuracy did not improve from 0.89293
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 449ms/step - accuracy: 0.9724 - loss: 0.0904 - val_accuracy: 0.8899 - val_loss: 0.3367 - learning_rate: 5.0000e-06
# Epoch 40/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9758 - loss: 0.0836
# Epoch 40: val_accuracy improved from 0.89293 to 0.89703, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 447ms/step - accuracy: 0.9758 - loss: 0.0836 - val_accuracy: 0.8970 - val_loss: 0.3086 - learning_rate: 2.5000e-06
# Epoch 41/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9807 - loss: 0.0763
# Epoch 41: val_accuracy improved from 0.89703 to 0.90163, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 449ms/step - accuracy: 0.9807 - loss: 0.0763 - val_accuracy: 0.9016 - val_loss: 0.3030 - learning_rate: 2.5000e-06
# Epoch 42/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9830 - loss: 0.0720
# Epoch 42: val_accuracy did not improve from 0.90163
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 196s 440ms/step - accuracy: 0.9830 - loss: 0.0720 - val_accuracy: 0.8945 - val_loss: 0.3177 - learning_rate: 2.5000e-06
# Epoch 43/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9814 - loss: 0.0699
# Epoch 43: val_accuracy did not improve from 0.90163
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 446ms/step - accuracy: 0.9814 - loss: 0.0699 - val_accuracy: 0.9000 - val_loss: 0.3127 - learning_rate: 2.5000e-06
# Epoch 44/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9847 - loss: 0.0639
# Epoch 44: val_accuracy did not improve from 0.90163
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 196s 440ms/step - accuracy: 0.9847 - loss: 0.0639 - val_accuracy: 0.8973 - val_loss: 0.3170 - learning_rate: 2.5000e-06
# Epoch 45/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9832 - loss: 0.0658
# Epoch 45: val_accuracy did not improve from 0.90163
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 196s 439ms/step - accuracy: 0.9832 - loss: 0.0658 - val_accuracy: 0.9003 - val_loss: 0.3057 - learning_rate: 1.2500e-06
# Epoch 46/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9832 - loss: 0.0619
# Epoch 46: val_accuracy improved from 0.90163 to 0.90180, saving model to best_ConvNeXtTiny_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 449ms/step - accuracy: 0.9832 - loss: 0.0619 - val_accuracy: 0.9018 - val_loss: 0.3058 - learning_rate: 1.2500e-06
# Epoch 47/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9854 - loss: 0.0617
# Epoch 47: val_accuracy improved from 0.90180 to 0.90381, saving model to best_ConvNeXtTiny_model.h5
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 199s 447ms/step - accuracy: 0.9854 - loss: 0.0617 - val_accuracy: 0.9038 - val_loss: 0.3039 - learning_rate: 1.2500e-06
# Epoch 48/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9861 - loss: 0.0582
# Epoch 48: val_accuracy did not improve from 0.90381
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9861 - loss: 0.0582 - val_accuracy: 0.9015 - val_loss: 0.3028 - learning_rate: 6.2500e-07
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 41.
# Training completed!
# {"id":"mruAz2qjjRHn","time":1755368289,"expires":1755411489,"event":"message","topic":"model_complete","message":"convnexttiny Train Complete"}

# %%
# Continue training for another 50 epochs starting from epoch 50
print("Starting extended training from epoch 50 to epoch 100...")
# !curl -d "convnexttiny Extended Train Start" ntfy.sh/model_complete

# Store the initial training history
initial_history = history.history.copy()

# Reset callbacks for extended training
checkpoint_cb_extended = ModelCheckpoint(
    "best_ConvNeXtTiny_model_extended.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb_extended = EarlyStopping(
    monitor="val_loss",
    patience=7, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr_extended = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

callbacks_extended = [checkpoint_cb_extended, earlystop_cb_extended, reduce_lr_extended]

# Continue training with initial_epoch parameter
extended_history = model.fit(
    train_flow,
    epochs=100,  # Total epochs (50 initial + 50 more)
    initial_epoch=50,  # Start from epoch 50
    validation_data=val_flow,
    callbacks=callbacks_extended,
    class_weight=class_weight_dict,
    verbose=1
)

print("Extended training completed!")
# !curl -d "convnexttiny Extended Train Complete" ntfy.sh/model_complete

# Combine the histories
combined_history = {}
for key in initial_history.keys():
    combined_history[key] = initial_history[key] + extended_history.history[key]

# Save combined training history
with open('combined_training_history.json', 'w') as f:
    json.dump(combined_history, f)

print(f"Total epochs completed: {len(combined_history['loss'])}")
print(f"Initial training epochs: 1-50")
print(f"Extended training epochs: 51-100")

# Update the history variable to use combined history for later plotting
class CombinedHistory:
    def __init__(self, combined_dict):
        self.history = combined_dict

history = CombinedHistory(combined_history)
# Out:
# Starting extended training from epoch 50 to epoch 100...
# {"id":"CP3wAMNTwZhJ","time":1755369847,"expires":1755413047,"event":"message","topic":"model_complete","message":"convnexttiny Extended Train Start"}
# Epoch 51/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9823 - loss: 0.0735
# Epoch 51: val_accuracy improved from -inf to 0.90046, saving model to best_ConvNeXtTiny_model_extended.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 208s 466ms/step - accuracy: 0.9823 - loss: 0.0735 - val_accuracy: 0.9005 - val_loss: 0.3013 - learning_rate: 6.2500e-07
# Epoch 52/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9837 - loss: 0.0677
# Epoch 52: val_accuracy improved from 0.90046 to 0.90130, saving model to best_ConvNeXtTiny_model_extended.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 450ms/step - accuracy: 0.9837 - loss: 0.0677 - val_accuracy: 0.9013 - val_loss: 0.3016 - learning_rate: 6.2500e-07
# Epoch 53/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9827 - loss: 0.0677
# Epoch 53: val_accuracy improved from 0.90130 to 0.90146, saving model to best_ConvNeXtTiny_model_extended.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 201s 452ms/step - accuracy: 0.9827 - loss: 0.0677 - val_accuracy: 0.9015 - val_loss: 0.2997 - learning_rate: 6.2500e-07
# Epoch 54/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9842 - loss: 0.0649
# Epoch 54: val_accuracy did not improve from 0.90146
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 443ms/step - accuracy: 0.9842 - loss: 0.0649 - val_accuracy: 0.9014 - val_loss: 0.3002 - learning_rate: 6.2500e-07
# Epoch 55/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9844 - loss: 0.0655
# Epoch 55: val_accuracy did not improve from 0.90146
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 443ms/step - accuracy: 0.9844 - loss: 0.0655 - val_accuracy: 0.9009 - val_loss: 0.3016 - learning_rate: 6.2500e-07
# Epoch 56/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9850 - loss: 0.0630
# Epoch 56: val_accuracy did not improve from 0.90146
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 200s 450ms/step - accuracy: 0.9850 - loss: 0.0630 - val_accuracy: 0.8995 - val_loss: 0.3020 - learning_rate: 6.2500e-07
# Epoch 57/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9832 - loss: 0.0676
# Epoch 57: val_accuracy did not improve from 0.90146
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 198s 445ms/step - accuracy: 0.9832 - loss: 0.0676 - val_accuracy: 0.9013 - val_loss: 0.2999 - learning_rate: 3.1250e-07
# Epoch 58/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9865 - loss: 0.0625
# Epoch 58: val_accuracy improved from 0.90146 to 0.90163, saving model to best_ConvNeXtTiny_model_extended.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 198s 446ms/step - accuracy: 0.9865 - loss: 0.0625 - val_accuracy: 0.9016 - val_loss: 0.2996 - learning_rate: 3.1250e-07
# Epoch 59/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9870 - loss: 0.0589
# Epoch 59: val_accuracy improved from 0.90163 to 0.90197, saving model to best_ConvNeXtTiny_model_extended.h5
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 197s 442ms/step - accuracy: 0.9870 - loss: 0.0589 - val_accuracy: 0.9020 - val_loss: 0.3019 - learning_rate: 3.1250e-07
# Epoch 60/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9842 - loss: 0.0635
# Epoch 60: val_accuracy did not improve from 0.90197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 198s 444ms/step - accuracy: 0.9842 - loss: 0.0635 - val_accuracy: 0.9020 - val_loss: 0.2999 - learning_rate: 1.5625e-07
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 53.
# Extended training completed!
# {"id":"pvfkwZGp9ETI","time":1755371843,"expires":1755415043,"event":"message","topic":"model_complete","message":"convnexttiny Extended Train Complete"}
# Total epochs completed: 58
# Initial training epochs: 1-50
# Extended training epochs: 51-100

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step
# Test Loss: 0.2969
# Test Accuracy: 0.9028
# Precision: 0.8671
# Recall: 0.8913
# F1 Score: 0.8768
# Parameters: 29309323

# %%
model.save('ConvNeXtTiny_final_model.keras')
model.save_weights('ConvNeXtTiny_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["ConvNeXtTiny"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# !curl -d "Finished" ntfy.sh/model_complete
# Out:
# | Model        |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:-------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | ConvNeXtTiny | 29309323 |      0.2969 |     0.9028 |      0.8671 |   0.8913 | 0.8768 |
# {"id":"nBEtY2H4pbA4","time":1755372426,"expires":1755415626,"event":"message","topic":"model_complete","message":"Finished"}
