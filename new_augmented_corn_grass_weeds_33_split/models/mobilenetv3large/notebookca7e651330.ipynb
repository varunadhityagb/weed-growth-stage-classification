# %%
import tensorflow as tf
# Out:
# 2025-08-17 11:07:45.974760: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755428866.162429      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755428866.221700      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 1e-5
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
# %% 
from tensorflow.keras.applications import MobileNetV3Large

base_model = MobileNetV3Large(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR,
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1755428898.683236      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 4,682,155
# Trainable parameters: 4,654,171

# %%
checkpoint_cb = ModelCheckpoint(
    "best_mobilenetv3large_model.h5",  # updated name
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"7An5MztdhaIw","time":1755428901,"expires":1755472101,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755428948.447655     115 service.cc:148] XLA service 0x786030001a20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755428948.448536     115 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755428952.731779     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1755428959.987023     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755428960.171535     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755428960.606183     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755428960.802773     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/445 ━━━━━━━━━━━━━━━━━━━━ 9:25:03 76s/step - accuracy: 0.0000e+00 - loss: 4.4959
# I0000 00:00:1755428978.541437     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 229/445 ━━━━━━━━━━━━━━━━━━━━ 1:10 327ms/step - accuracy: 0.0196 - loss: 4.4421
# E0000 00:00:1755429061.858369     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755429062.040684     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755429062.226495     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755429062.410723     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755429062.802468     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755429063.001544     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.0206 - loss: 4.4135
# Epoch 1: val_accuracy improved from -inf to 0.03890, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 375s 673ms/step - accuracy: 0.0206 - loss: 4.4134 - val_accuracy: 0.0389 - val_loss: 3.9541 - learning_rate: 1.0000e-05
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.0314 - loss: 4.1924
# Epoch 2: val_accuracy did not improve from 0.03890
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.0314 - loss: 4.1923 - val_accuracy: 0.0372 - val_loss: 3.9845 - learning_rate: 1.0000e-05
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.0390 - loss: 4.0261
# Epoch 3: val_accuracy did not improve from 0.03890
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.0390 - loss: 4.0260 - val_accuracy: 0.0198 - val_loss: 3.8412 - learning_rate: 1.0000e-05
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.0626 - loss: 3.8128
# Epoch 4: val_accuracy did not improve from 0.03890
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 98s 221ms/step - accuracy: 0.0626 - loss: 3.8127 - val_accuracy: 0.0243 - val_loss: 3.7934 - learning_rate: 1.0000e-05
# Epoch 5/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.0862 - loss: 3.6296
# Epoch 5: val_accuracy did not improve from 0.03890
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 214ms/step - accuracy: 0.0862 - loss: 3.6295 - val_accuracy: 0.0374 - val_loss: 3.7919 - learning_rate: 1.0000e-05
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1053 - loss: 3.4705
# Epoch 6: val_accuracy improved from 0.03890 to 0.05655, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.1054 - loss: 3.4704 - val_accuracy: 0.0565 - val_loss: 3.7502 - learning_rate: 1.0000e-05
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.1683 - loss: 3.1377
# Epoch 8: val_accuracy improved from 0.06340 to 0.06842, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.1683 - loss: 3.1376 - val_accuracy: 0.0684 - val_loss: 3.6496 - learning_rate: 1.0000e-05
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.1930 - loss: 2.9964
# Epoch 9: val_accuracy improved from 0.06842 to 0.08984, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.1931 - loss: 2.9963 - val_accuracy: 0.0898 - val_loss: 3.5472 - learning_rate: 1.0000e-05
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2144 - loss: 2.8844
# Epoch 10: val_accuracy improved from 0.08984 to 0.10238, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.2144 - loss: 2.8843 - val_accuracy: 0.1024 - val_loss: 3.4572 - learning_rate: 1.0000e-05
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2506 - loss: 2.7220
# Epoch 11: val_accuracy improved from 0.10238 to 0.14697, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.2506 - loss: 2.7220 - val_accuracy: 0.1470 - val_loss: 3.2193 - learning_rate: 1.0000e-05
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.2619 - loss: 2.6101
# Epoch 12: val_accuracy improved from 0.14697 to 0.18151, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.2619 - loss: 2.6101 - val_accuracy: 0.1815 - val_loss: 3.0241 - learning_rate: 1.0000e-05
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.2918 - loss: 2.4880
# Epoch 13: val_accuracy improved from 0.18151 to 0.24191, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 97s 218ms/step - accuracy: 0.2918 - loss: 2.4879 - val_accuracy: 0.2419 - val_loss: 2.7036 - learning_rate: 1.0000e-05
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3024 - loss: 2.3972
# Epoch 14: val_accuracy improved from 0.24191 to 0.28800, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 210ms/step - accuracy: 0.3024 - loss: 2.3971 - val_accuracy: 0.2880 - val_loss: 2.4518 - learning_rate: 1.0000e-05
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3315 - loss: 2.2769
# Epoch 15: val_accuracy improved from 0.28800 to 0.33091, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 96s 215ms/step - accuracy: 0.3315 - loss: 2.2768 - val_accuracy: 0.3309 - val_loss: 2.2132 - learning_rate: 1.0000e-05
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3535 - loss: 2.1774
# Epoch 16: val_accuracy improved from 0.33091 to 0.35609, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.3535 - loss: 2.1774 - val_accuracy: 0.3561 - val_loss: 2.0993 - learning_rate: 1.0000e-05
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3620 - loss: 2.1019
# Epoch 17: val_accuracy improved from 0.35609 to 0.38645, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 97s 217ms/step - accuracy: 0.3620 - loss: 2.1019 - val_accuracy: 0.3864 - val_loss: 1.9704 - learning_rate: 1.0000e-05
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3905 - loss: 2.0064
# Epoch 18: val_accuracy improved from 0.38645 to 0.39724, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.3905 - loss: 2.0064 - val_accuracy: 0.3972 - val_loss: 1.9489 - learning_rate: 1.0000e-05
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4106 - loss: 1.9251
# Epoch 19: val_accuracy improved from 0.39724 to 0.45889, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 214ms/step - accuracy: 0.4105 - loss: 1.9251 - val_accuracy: 0.4589 - val_loss: 1.7083 - learning_rate: 1.0000e-05
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4300 - loss: 1.8438
# Epoch 20: val_accuracy improved from 0.45889 to 0.46324, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.4300 - loss: 1.8438 - val_accuracy: 0.4632 - val_loss: 1.6450 - learning_rate: 1.0000e-05
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4376 - loss: 1.7918
# Epoch 21: val_accuracy improved from 0.46324 to 0.48900, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 106s 238ms/step - accuracy: 0.4376 - loss: 1.7918 - val_accuracy: 0.4890 - val_loss: 1.5641 - learning_rate: 1.0000e-05
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4602 - loss: 1.7045
# Epoch 22: val_accuracy improved from 0.48900 to 0.51451, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.4602 - loss: 1.7045 - val_accuracy: 0.5145 - val_loss: 1.4891 - learning_rate: 1.0000e-05
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4795 - loss: 1.6344
# Epoch 23: val_accuracy improved from 0.51451 to 0.54145, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 121s 272ms/step - accuracy: 0.4795 - loss: 1.6344 - val_accuracy: 0.5414 - val_loss: 1.4127 - learning_rate: 1.0000e-05
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4988 - loss: 1.5688
# Epoch 24: val_accuracy improved from 0.54145 to 0.54563, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 96s 217ms/step - accuracy: 0.4988 - loss: 1.5688 - val_accuracy: 0.5456 - val_loss: 1.3848 - learning_rate: 1.0000e-05
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5250 - loss: 1.4958
# Epoch 25: val_accuracy improved from 0.54563 to 0.56161, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 103s 232ms/step - accuracy: 0.5250 - loss: 1.4958 - val_accuracy: 0.5616 - val_loss: 1.3266 - learning_rate: 1.0000e-05
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5397 - loss: 1.4213
# Epoch 26: val_accuracy did not improve from 0.56161
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 101s 228ms/step - accuracy: 0.5397 - loss: 1.4213 - val_accuracy: 0.2683 - val_loss: 4.6161 - learning_rate: 1.0000e-05
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5540 - loss: 1.3788
# Epoch 27: val_accuracy did not improve from 0.56161
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 107s 241ms/step - accuracy: 0.5540 - loss: 1.3788 - val_accuracy: 0.1836 - val_loss: 52.0346 - learning_rate: 1.0000e-05
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5744 - loss: 1.3094
# Epoch 28: val_accuracy did not improve from 0.56161
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 265ms/step - accuracy: 0.5744 - loss: 1.3094 - val_accuracy: 0.0826 - val_loss: 679.7021 - learning_rate: 1.0000e-05
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5849 - loss: 1.2758
# Epoch 29: val_accuracy improved from 0.56161 to 0.62551, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 104s 234ms/step - accuracy: 0.5849 - loss: 1.2757 - val_accuracy: 0.6255 - val_loss: 1.1121 - learning_rate: 1.0000e-05
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5951 - loss: 1.2180
# Epoch 30: val_accuracy improved from 0.62551 to 0.64316, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.5951 - loss: 1.2179 - val_accuracy: 0.6432 - val_loss: 1.0469 - learning_rate: 1.0000e-05
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6196 - loss: 1.1542
# Epoch 31: val_accuracy did not improve from 0.64316
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 119s 267ms/step - accuracy: 0.6196 - loss: 1.1542 - val_accuracy: 0.1088 - val_loss: 180.9879 - learning_rate: 1.0000e-05
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6524 - loss: 1.0773
# Epoch 32: val_accuracy did not improve from 0.64316
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 144s 324ms/step - accuracy: 0.6524 - loss: 1.0774 - val_accuracy: 0.2048 - val_loss: 38.8077 - learning_rate: 1.0000e-05
# Epoch 33/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6504 - loss: 1.0422
# Epoch 33: val_accuracy improved from 0.64316 to 0.64776, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 255ms/step - accuracy: 0.6504 - loss: 1.0421 - val_accuracy: 0.6478 - val_loss: 1.0083 - learning_rate: 1.0000e-05
# Epoch 34/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6769 - loss: 1.0036
# Epoch 34: val_accuracy did not improve from 0.64776
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 102s 230ms/step - accuracy: 0.6769 - loss: 1.0036 - val_accuracy: 0.4710 - val_loss: 1.8404 - learning_rate: 1.0000e-05
# Epoch 35/100
# 425/445 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.6883 - loss: 0.9491

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 57s 151ms/step
# Test Loss: 0.5631
# Test Accuracy: 0.7985
# Precision: 0.7566
# Recall: 0.8039
# F1 Score: 0.7506
# Parameters: 4682155

# %%
model.save('mobilenetv3large_final_model.keras')
model.save_weights('mobilenetv3large_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["MobileNetV3Large"],
    "Params": [num_params],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()
# Out:
# | Model            |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:-----------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | MobileNetV3Large |  4682155 |      0.5631 |     0.7985 |      0.7566 |   0.8039 | 0.7506 |
