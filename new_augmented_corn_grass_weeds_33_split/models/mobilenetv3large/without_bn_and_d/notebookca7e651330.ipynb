# %%
import tensorflow as tf
# Out:
# 2025-08-23 14:48:30.752857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755960510.957078      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755960511.015881      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 1e-5
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
# %% 
from tensorflow.keras.applications import MobileNetV3Large

base_model = MobileNetV3Large(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR,
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1755960530.761487      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 4,674,987
# Trainable parameters: 4,650,587

# %%
checkpoint_cb = ModelCheckpoint(
    "best_mobilenetv3large_model.h5",  # updated name
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"YchBz2ebPbHD","time":1755960533,"expires":1756003733,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755960577.812161     115 service.cc:148] XLA service 0x7fb99c0022a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755960577.813035     115 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755960581.836061     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1755960587.593268     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960587.779200     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960588.217554     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960588.414826     115 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/445 ━━━━━━━━━━━━━━━━━━━━ 8:34:09 69s/step - accuracy: 0.0312 - loss: 3.7380
# I0000 00:00:1755960603.501825     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  39/445 ━━━━━━━━━━━━━━━━━━━━ 1:22 203ms/step - accuracy: 0.0325 - loss: 3.7729
# E0000 00:00:1755960618.360794     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960618.543174     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960618.933864     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755960619.130028     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.0576 - loss: 3.6618
# Epoch 1: val_accuracy improved from -inf to 0.04049, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 265s 441ms/step - accuracy: 0.0577 - loss: 3.6615 - val_accuracy: 0.0405 - val_loss: 3.7455 - learning_rate: 1.0000e-05
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2389 - loss: 2.8558
# Epoch 2: val_accuracy did not improve from 0.04049
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.2390 - loss: 2.8553 - val_accuracy: 0.0348 - val_loss: 3.7163 - learning_rate: 1.0000e-05
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.4500 - loss: 1.9868
# Epoch 3: val_accuracy improved from 0.04049 to 0.04517, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.4501 - loss: 1.9865 - val_accuracy: 0.0452 - val_loss: 3.7001 - learning_rate: 1.0000e-05
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6450 - loss: 1.1494
# Epoch 5: val_accuracy did not improve from 0.04985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.6451 - loss: 1.1493 - val_accuracy: 0.0454 - val_loss: 3.8227 - learning_rate: 1.0000e-05
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7119 - loss: 0.9275
# Epoch 6: val_accuracy improved from 0.04985 to 0.05738, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.7119 - loss: 0.9274 - val_accuracy: 0.0574 - val_loss: 3.8942 - learning_rate: 1.0000e-05
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7483 - loss: 0.7898
# Epoch 7: val_accuracy improved from 0.05738 to 0.06248, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.7483 - loss: 0.7898 - val_accuracy: 0.0625 - val_loss: 3.9772 - learning_rate: 1.0000e-05
# Epoch 8/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7846 - loss: 0.6749
# Epoch 8: val_accuracy improved from 0.06248 to 0.08122, saving model to best_mobilenetv3large_model.h5
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 207ms/step - accuracy: 0.7846 - loss: 0.6749 - val_accuracy: 0.0812 - val_loss: 3.8376 - learning_rate: 1.0000e-05
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8226 - loss: 0.5649
# Epoch 9: val_accuracy improved from 0.08122 to 0.11418, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.8226 - loss: 0.5649 - val_accuracy: 0.1142 - val_loss: 3.5125 - learning_rate: 5.0000e-06
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8301 - loss: 0.5237
# Epoch 10: val_accuracy improved from 0.11418 to 0.15784, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.8301 - loss: 0.5237 - val_accuracy: 0.1578 - val_loss: 3.1784 - learning_rate: 5.0000e-06
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8492 - loss: 0.4791
# Epoch 11: val_accuracy improved from 0.15784 to 0.22350, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 204ms/step - accuracy: 0.8492 - loss: 0.4791 - val_accuracy: 0.2235 - val_loss: 2.8257 - learning_rate: 5.0000e-06
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8575 - loss: 0.4534
# Epoch 12: val_accuracy improved from 0.22350 to 0.29427, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.8575 - loss: 0.4534 - val_accuracy: 0.2943 - val_loss: 2.3711 - learning_rate: 5.0000e-06
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8672 - loss: 0.4181
# Epoch 13: val_accuracy improved from 0.29427 to 0.41489, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.8672 - loss: 0.4181 - val_accuracy: 0.4149 - val_loss: 1.8229 - learning_rate: 5.0000e-06
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8845 - loss: 0.3877
# Epoch 14: val_accuracy improved from 0.41489 to 0.54638, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 98s 220ms/step - accuracy: 0.8845 - loss: 0.3877 - val_accuracy: 0.5464 - val_loss: 1.3491 - learning_rate: 5.0000e-06
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8821 - loss: 0.3744
# Epoch 15: val_accuracy improved from 0.54638 to 0.62359, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 99s 221ms/step - accuracy: 0.8821 - loss: 0.3744 - val_accuracy: 0.6236 - val_loss: 1.0739 - learning_rate: 5.0000e-06
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8899 - loss: 0.3487
# Epoch 16: val_accuracy did not improve from 0.62359
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.8899 - loss: 0.3487 - val_accuracy: 0.6079 - val_loss: 1.1798 - learning_rate: 5.0000e-06
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9022 - loss: 0.3196
# Epoch 17: val_accuracy improved from 0.62359 to 0.68122, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 210ms/step - accuracy: 0.9022 - loss: 0.3196 - val_accuracy: 0.6812 - val_loss: 0.9415 - learning_rate: 5.0000e-06
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9085 - loss: 0.3039
# Epoch 18: val_accuracy did not improve from 0.68122
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.9085 - loss: 0.3039 - val_accuracy: 0.5985 - val_loss: 1.3197 - learning_rate: 5.0000e-06
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9141 - loss: 0.2844
# Epoch 19: val_accuracy did not improve from 0.68122
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.9141 - loss: 0.2844 - val_accuracy: 0.5725 - val_loss: 1.5214 - learning_rate: 5.0000e-06
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9194 - loss: 0.2660
# Epoch 20: val_accuracy did not improve from 0.68122
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 207ms/step - accuracy: 0.9194 - loss: 0.2660 - val_accuracy: 0.5455 - val_loss: 1.7128 - learning_rate: 5.0000e-06
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9279 - loss: 0.2452
# Epoch 21: val_accuracy improved from 0.68122 to 0.76621, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9279 - loss: 0.2453 - val_accuracy: 0.7662 - val_loss: 0.6792 - learning_rate: 5.0000e-06
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9354 - loss: 0.2331
# Epoch 22: val_accuracy did not improve from 0.76621
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 214ms/step - accuracy: 0.9354 - loss: 0.2331 - val_accuracy: 0.7201 - val_loss: 0.8815 - learning_rate: 5.0000e-06
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9394 - loss: 0.2191
# Epoch 23: val_accuracy did not improve from 0.76621
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9394 - loss: 0.2191 - val_accuracy: 0.5781 - val_loss: 1.6992 - learning_rate: 5.0000e-06
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9418 - loss: 0.2076
# Epoch 24: val_accuracy improved from 0.76621 to 0.77432, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 208ms/step - accuracy: 0.9418 - loss: 0.2076 - val_accuracy: 0.7743 - val_loss: 0.6588 - learning_rate: 5.0000e-06
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9453 - loss: 0.1931
# Epoch 25: val_accuracy did not improve from 0.77432
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.9453 - loss: 0.1931 - val_accuracy: 0.7590 - val_loss: 0.7294 - learning_rate: 5.0000e-06
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9468 - loss: 0.1811
# Epoch 26: val_accuracy did not improve from 0.77432
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.9468 - loss: 0.1811 - val_accuracy: 0.7450 - val_loss: 0.7965 - learning_rate: 5.0000e-06
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9504 - loss: 0.1748
# Epoch 27: val_accuracy improved from 0.77432 to 0.77583, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 210ms/step - accuracy: 0.9504 - loss: 0.1748 - val_accuracy: 0.7758 - val_loss: 0.6767 - learning_rate: 5.0000e-06
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9522 - loss: 0.1678
# Epoch 28: val_accuracy improved from 0.77583 to 0.83312, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9522 - loss: 0.1678 - val_accuracy: 0.8331 - val_loss: 0.4762 - learning_rate: 5.0000e-06
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9589 - loss: 0.1493
# Epoch 29: val_accuracy improved from 0.83312 to 0.83463, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 203ms/step - accuracy: 0.9589 - loss: 0.1493 - val_accuracy: 0.8346 - val_loss: 0.4645 - learning_rate: 5.0000e-06
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9664 - loss: 0.1323
# Epoch 30: val_accuracy did not improve from 0.83463
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.9664 - loss: 0.1323 - val_accuracy: 0.6793 - val_loss: 1.2257 - learning_rate: 5.0000e-06
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9652 - loss: 0.1359
# Epoch 31: val_accuracy did not improve from 0.83463
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 204ms/step - accuracy: 0.9652 - loss: 0.1359 - val_accuracy: 0.7206 - val_loss: 0.9815 - learning_rate: 5.0000e-06
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9706 - loss: 0.1222
# Epoch 32: val_accuracy improved from 0.83463 to 0.84550, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 203ms/step - accuracy: 0.9706 - loss: 0.1222 - val_accuracy: 0.8455 - val_loss: 0.4328 - learning_rate: 5.0000e-06
# Epoch 33/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9732 - loss: 0.1161
# Epoch 33: val_accuracy improved from 0.84550 to 0.84952, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9732 - loss: 0.1161 - val_accuracy: 0.8495 - val_loss: 0.4195 - learning_rate: 5.0000e-06
# Epoch 34/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9744 - loss: 0.1134
# Epoch 34: val_accuracy did not improve from 0.84952
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9744 - loss: 0.1134 - val_accuracy: 0.4008 - val_loss: 6.4219 - learning_rate: 5.0000e-06
# Epoch 35/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9736 - loss: 0.1046
# Epoch 35: val_accuracy did not improve from 0.84952
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9736 - loss: 0.1046 - val_accuracy: 0.4853 - val_loss: 2.7546 - learning_rate: 5.0000e-06
# Epoch 36/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9769 - loss: 0.0969
# Epoch 36: val_accuracy did not improve from 0.84952
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 203ms/step - accuracy: 0.9769 - loss: 0.0969 - val_accuracy: 0.5329 - val_loss: 2.5536 - learning_rate: 5.0000e-06
# Epoch 37/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9778 - loss: 0.0947
# Epoch 37: val_accuracy did not improve from 0.84952
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.9778 - loss: 0.0947 - val_accuracy: 0.6294 - val_loss: 1.6592 - learning_rate: 5.0000e-06
# Epoch 38/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9811 - loss: 0.0838
# Epoch 38: val_accuracy improved from 0.84952 to 0.85922, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9811 - loss: 0.0838 - val_accuracy: 0.8592 - val_loss: 0.4020 - learning_rate: 5.0000e-06
# Epoch 39/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9820 - loss: 0.0818
# Epoch 39: val_accuracy improved from 0.85922 to 0.86182, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9820 - loss: 0.0818 - val_accuracy: 0.8618 - val_loss: 0.3970 - learning_rate: 5.0000e-06
# Epoch 40/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9861 - loss: 0.0724
# Epoch 40: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 102s 230ms/step - accuracy: 0.9861 - loss: 0.0724 - val_accuracy: 0.8451 - val_loss: 0.4570 - learning_rate: 5.0000e-06
# Epoch 41/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9826 - loss: 0.0742
# Epoch 41: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.9826 - loss: 0.0742 - val_accuracy: 0.7783 - val_loss: 0.7238 - learning_rate: 5.0000e-06
# Epoch 42/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9876 - loss: 0.0667
# Epoch 42: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 212ms/step - accuracy: 0.9875 - loss: 0.0667 - val_accuracy: 0.6067 - val_loss: 1.9518 - learning_rate: 5.0000e-06
# Epoch 43/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9846 - loss: 0.0686
# Epoch 43: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9846 - loss: 0.0686 - val_accuracy: 0.7174 - val_loss: 1.1346 - learning_rate: 5.0000e-06
# Epoch 44/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9887 - loss: 0.0602
# Epoch 44: val_accuracy did not improve from 0.86182
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9887 - loss: 0.0602 - val_accuracy: 0.7657 - val_loss: 0.8247 - learning_rate: 5.0000e-06
# Epoch 45/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9888 - loss: 0.0561
# Epoch 45: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9888 - loss: 0.0561 - val_accuracy: 0.8116 - val_loss: 0.5929 - learning_rate: 2.5000e-06
# Epoch 46/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9881 - loss: 0.0547
# Epoch 46: val_accuracy did not improve from 0.86182
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 201ms/step - accuracy: 0.9881 - loss: 0.0547 - val_accuracy: 0.7153 - val_loss: 1.1322 - learning_rate: 2.5000e-06
# Epoch 47/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9911 - loss: 0.0489
# Epoch 47: val_accuracy improved from 0.86182 to 0.86708, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 203ms/step - accuracy: 0.9911 - loss: 0.0489 - val_accuracy: 0.8671 - val_loss: 0.3980 - learning_rate: 2.5000e-06
# Epoch 48/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9900 - loss: 0.0521
# Epoch 48: val_accuracy improved from 0.86708 to 0.86901, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 207ms/step - accuracy: 0.9900 - loss: 0.0521 - val_accuracy: 0.8690 - val_loss: 0.3914 - learning_rate: 2.5000e-06
# Epoch 49/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9923 - loss: 0.0475
# Epoch 49: val_accuracy did not improve from 0.86901
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9923 - loss: 0.0475 - val_accuracy: 0.8642 - val_loss: 0.3999 - learning_rate: 2.5000e-06
# Epoch 50/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9912 - loss: 0.0498
# Epoch 50: val_accuracy improved from 0.86901 to 0.86943, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 203ms/step - accuracy: 0.9912 - loss: 0.0498 - val_accuracy: 0.8694 - val_loss: 0.3877 - learning_rate: 2.5000e-06
# Epoch 51/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9922 - loss: 0.0435
# Epoch 51: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 204ms/step - accuracy: 0.9922 - loss: 0.0435 - val_accuracy: 0.8671 - val_loss: 0.3945 - learning_rate: 2.5000e-06
# Epoch 52/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9885 - loss: 0.0490
# Epoch 52: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 210ms/step - accuracy: 0.9885 - loss: 0.0490 - val_accuracy: 0.8012 - val_loss: 0.6550 - learning_rate: 2.5000e-06
# Epoch 53/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9931 - loss: 0.0420
# Epoch 53: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9931 - loss: 0.0420 - val_accuracy: 0.8672 - val_loss: 0.3986 - learning_rate: 2.5000e-06
# Epoch 54/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9907 - loss: 0.0434
# Epoch 54: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 210ms/step - accuracy: 0.9907 - loss: 0.0434 - val_accuracy: 0.8690 - val_loss: 0.3947 - learning_rate: 2.5000e-06
# Epoch 55/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9917 - loss: 0.0403
# Epoch 55: val_accuracy did not improve from 0.86943
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 98s 221ms/step - accuracy: 0.9917 - loss: 0.0403 - val_accuracy: 0.8627 - val_loss: 0.4239 - learning_rate: 2.5000e-06
# Epoch 56/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9931 - loss: 0.0405
# Epoch 56: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 96s 216ms/step - accuracy: 0.9931 - loss: 0.0405 - val_accuracy: 0.8504 - val_loss: 0.4592 - learning_rate: 1.2500e-06
# Epoch 57/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9957 - loss: 0.0353
# Epoch 57: val_accuracy did not improve from 0.86943
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 210ms/step - accuracy: 0.9957 - loss: 0.0353 - val_accuracy: 0.8660 - val_loss: 0.4082 - learning_rate: 1.2500e-06
# Epoch 58/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9933 - loss: 0.0376
# Epoch 58: val_accuracy improved from 0.86943 to 0.86993, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 96s 216ms/step - accuracy: 0.9933 - loss: 0.0376 - val_accuracy: 0.8699 - val_loss: 0.3944 - learning_rate: 1.2500e-06
# Epoch 59/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9931 - loss: 0.0364
# Epoch 59: val_accuracy improved from 0.86993 to 0.87378, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9931 - loss: 0.0364 - val_accuracy: 0.8738 - val_loss: 0.3861 - learning_rate: 1.2500e-06
# Epoch 60/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9948 - loss: 0.0347
# Epoch 60: val_accuracy did not improve from 0.87378
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 97s 218ms/step - accuracy: 0.9948 - loss: 0.0347 - val_accuracy: 0.8674 - val_loss: 0.4043 - learning_rate: 1.2500e-06
# Epoch 61/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9950 - loss: 0.0338
# Epoch 61: val_accuracy did not improve from 0.87378
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.9950 - loss: 0.0338 - val_accuracy: 0.8633 - val_loss: 0.4210 - learning_rate: 1.2500e-06
# Epoch 62/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9943 - loss: 0.0349
# Epoch 62: val_accuracy did not improve from 0.87378
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9943 - loss: 0.0349 - val_accuracy: 0.8734 - val_loss: 0.3895 - learning_rate: 1.2500e-06
# Epoch 63/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9943 - loss: 0.0339
# Epoch 63: val_accuracy improved from 0.87378 to 0.87411, saving model to best_mobilenetv3large_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9943 - loss: 0.0339 - val_accuracy: 0.8741 - val_loss: 0.3890 - learning_rate: 1.2500e-06
# Epoch 64/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9932 - loss: 0.0357
# Epoch 64: val_accuracy did not improve from 0.87411
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 207ms/step - accuracy: 0.9932 - loss: 0.0357 - val_accuracy: 0.8703 - val_loss: 0.3988 - learning_rate: 1.2500e-06
# Epoch 65/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9941 - loss: 0.0335
# Epoch 65: val_accuracy did not improve from 0.87411
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 208ms/step - accuracy: 0.9941 - loss: 0.0335 - val_accuracy: 0.8735 - val_loss: 0.3933 - learning_rate: 6.2500e-07
# Epoch 66/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9961 - loss: 0.0302
# Epoch 66: val_accuracy did not improve from 0.87411
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9961 - loss: 0.0302 - val_accuracy: 0.8689 - val_loss: 0.4046 - learning_rate: 6.2500e-07
# Epoch 67/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9945 - loss: 0.0329
# Epoch 67: val_accuracy did not improve from 0.87411
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 203ms/step - accuracy: 0.9945 - loss: 0.0329 - val_accuracy: 0.8675 - val_loss: 0.4126 - learning_rate: 6.2500e-07
# Epoch 68/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9949 - loss: 0.0311
# Epoch 68: val_accuracy did not improve from 0.87411
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9949 - loss: 0.0311 - val_accuracy: 0.8705 - val_loss: 0.3922 - learning_rate: 6.2500e-07
# Epoch 69/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9950 - loss: 0.0324
# Epoch 69: val_accuracy did not improve from 0.87411
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.9950 - loss: 0.0324 - val_accuracy: 0.8664 - val_loss: 0.4144 - learning_rate: 6.2500e-07
# Epoch 69: early stopping
# Restoring model weights from the end of the best epoch: 59.
# Training completed!
# {"id":"ZrMAeXkoJm0u","time":1755967127,"expires":1756010327,"event":"message","topic":"model_complete","message":"Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 97s 244ms/step
# Test Loss: 0.3896
# Test Accuracy: 0.8750
# Precision: 0.8509
# Recall: 0.8579
# F1 Score: 0.8514
# Parameters: 4674987

# %%
model.save('mobilenetv3large_final_model.keras')
model.save_weights('mobilenetv3large_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["MobileNetV3Large"],
    "Params": [num_params],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()
# Out:
# | Model            |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:-----------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | MobileNetV3Large |  4674987 |      0.3896 |      0.875 |      0.8509 |   0.8579 | 0.8514 |
