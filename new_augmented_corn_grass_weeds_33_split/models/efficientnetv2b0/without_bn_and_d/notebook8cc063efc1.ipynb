# %%
import tensorflow as tf
# Out:
# 2025-08-23 18:08:31.813077: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755972512.016772      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755972512.076786      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = EfficientNetV2B0(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=output)


optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1755972538.003392      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 7,925,627
# Trainable parameters: 7,865,019

# %%
checkpoint_cb = ModelCheckpoint(
    "best_EfficientNetV2B0_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("efficientnetv2b0 Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "efficientnetv2b0 Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# efficientnetv2b0 Starting training
# {"id":"3ChH47GTId9b","time":1755972541,"expires":1756015741,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755972607.322704     113 service.cc:148] XLA service 0x7acff4003460 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755972607.323481     113 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755972613.347079     113 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1755972623.019106     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972623.204419     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972623.670059     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972623.876213     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/445 ━━━━━━━━━━━━━━━━━━━━ 12:36:22 102s/step - accuracy: 0.0312 - loss: 3.7537
# I0000 00:00:1755972644.168673     113 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 251/445 ━━━━━━━━━━━━━━━━━━━━ 47s 243ms/step - accuracy: 0.2247 - loss: 2.7078
# E0000 00:00:1755972716.877212     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972717.058810     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972717.472975     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1755972717.677524     113 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.2901 - loss: 2.3825
# Epoch 1: val_accuracy improved from -inf to 0.04040, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 345s 547ms/step - accuracy: 0.2904 - loss: 2.3812 - val_accuracy: 0.0404 - val_loss: 4.3118 - learning_rate: 0.0010
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6491 - loss: 0.9966
# Epoch 2: val_accuracy did not improve from 0.04040
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 97s 218ms/step - accuracy: 0.6492 - loss: 0.9964 - val_accuracy: 0.0403 - val_loss: 5.4137 - learning_rate: 0.0010
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7720 - loss: 0.6352
# Epoch 3: val_accuracy improved from 0.04040 to 0.04684, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 97s 217ms/step - accuracy: 0.7720 - loss: 0.6351 - val_accuracy: 0.0468 - val_loss: 4.5168 - learning_rate: 0.0010
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8327 - loss: 0.4619
# Epoch 4: val_accuracy improved from 0.04684 to 0.06600, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 207ms/step - accuracy: 0.8327 - loss: 0.4619 - val_accuracy: 0.0660 - val_loss: 4.4858 - learning_rate: 0.0010
# Epoch 5/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8759 - loss: 0.3576
# Epoch 5: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.8759 - loss: 0.3576 - val_accuracy: 0.0300 - val_loss: 4.0791 - learning_rate: 0.0010
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8899 - loss: 0.3151
# Epoch 6: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 204ms/step - accuracy: 0.8899 - loss: 0.3151 - val_accuracy: 0.0025 - val_loss: 6.4463 - learning_rate: 0.0010
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9046 - loss: 0.2917
# Epoch 7: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9046 - loss: 0.2917 - val_accuracy: 0.0369 - val_loss: 5.3444 - learning_rate: 0.0010
# Epoch 8/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9215 - loss: 0.2503
# Epoch 8: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 212ms/step - accuracy: 0.9215 - loss: 0.2503 - val_accuracy: 0.0403 - val_loss: 3.8977 - learning_rate: 0.0010
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9244 - loss: 0.2349
# Epoch 9: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 200ms/step - accuracy: 0.9244 - loss: 0.2349 - val_accuracy: 0.0196 - val_loss: 5.7607 - learning_rate: 0.0010
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9260 - loss: 0.2292
# Epoch 10: val_accuracy did not improve from 0.06600
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9260 - loss: 0.2292 - val_accuracy: 0.0247 - val_loss: 5.0646 - learning_rate: 0.0010
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9387 - loss: 0.1973
# Epoch 11: val_accuracy improved from 0.06600 to 0.06734, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9387 - loss: 0.1973 - val_accuracy: 0.0673 - val_loss: 5.1782 - learning_rate: 0.0010
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9409 - loss: 0.1754
# Epoch 12: val_accuracy did not improve from 0.06734
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 209ms/step - accuracy: 0.9409 - loss: 0.1754 - val_accuracy: 0.0175 - val_loss: 17.4873 - learning_rate: 0.0010
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9421 - loss: 0.1850
# Epoch 13: val_accuracy did not improve from 0.06734
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 212ms/step - accuracy: 0.9421 - loss: 0.1850 - val_accuracy: 0.0402 - val_loss: 4.9511 - learning_rate: 0.0010
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9779 - loss: 0.0746
# Epoch 14: val_accuracy improved from 0.06734 to 0.49092, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 213ms/step - accuracy: 0.9780 - loss: 0.0746 - val_accuracy: 0.4909 - val_loss: 2.1870 - learning_rate: 5.0000e-04
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9880 - loss: 0.0387
# Epoch 15: val_accuracy did not improve from 0.49092
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9879 - loss: 0.0387 - val_accuracy: 0.0960 - val_loss: 4.4351 - learning_rate: 5.0000e-04
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9888 - loss: 0.0407
# Epoch 16: val_accuracy did not improve from 0.49092
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 201ms/step - accuracy: 0.9888 - loss: 0.0407 - val_accuracy: 0.2505 - val_loss: 3.3579 - learning_rate: 5.0000e-04
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9912 - loss: 0.0302
# Epoch 17: val_accuracy did not improve from 0.49092
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9912 - loss: 0.0303 - val_accuracy: 0.0268 - val_loss: 6.1944 - learning_rate: 5.0000e-04
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9846 - loss: 0.0605
# Epoch 18: val_accuracy did not improve from 0.49092
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 214ms/step - accuracy: 0.9846 - loss: 0.0604 - val_accuracy: 0.0958 - val_loss: 4.6339 - learning_rate: 5.0000e-04
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9850 - loss: 0.0518
# Epoch 19: val_accuracy did not improve from 0.49092
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 201ms/step - accuracy: 0.9850 - loss: 0.0519 - val_accuracy: 0.0175 - val_loss: 6.4915 - learning_rate: 5.0000e-04
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9916 - loss: 0.0252
# Epoch 20: val_accuracy did not improve from 0.49092
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 199ms/step - accuracy: 0.9916 - loss: 0.0252 - val_accuracy: 0.0370 - val_loss: 5.0994 - learning_rate: 2.5000e-04
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9957 - loss: 0.0131
# Epoch 21: val_accuracy improved from 0.49092 to 0.85713, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 95s 214ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.8571 - val_loss: 0.5723 - learning_rate: 2.5000e-04
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9977 - loss: 0.0074
# Epoch 22: val_accuracy did not improve from 0.85713
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 211ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.3015 - val_loss: 3.1234 - learning_rate: 2.5000e-04
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9964 - loss: 0.0138
# Epoch 23: val_accuracy did not improve from 0.85713
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 88s 199ms/step - accuracy: 0.9964 - loss: 0.0138 - val_accuracy: 0.5136 - val_loss: 2.4300 - learning_rate: 2.5000e-04
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9969 - loss: 0.0101
# Epoch 24: val_accuracy did not improve from 0.85713
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 88s 197ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.1643 - val_loss: 4.9496 - learning_rate: 2.5000e-04
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9973 - loss: 0.0095
# Epoch 25: val_accuracy did not improve from 0.85713
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 199ms/step - accuracy: 0.9973 - loss: 0.0095 - val_accuracy: 0.0309 - val_loss: 5.2158 - learning_rate: 2.5000e-04
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9945 - loss: 0.0190
# Epoch 26: val_accuracy did not improve from 0.85713
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 201ms/step - accuracy: 0.9945 - loss: 0.0189 - val_accuracy: 0.4862 - val_loss: 2.2708 - learning_rate: 2.5000e-04
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9966 - loss: 0.0094
# Epoch 27: val_accuracy did not improve from 0.85713
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 89s 200ms/step - accuracy: 0.9966 - loss: 0.0094 - val_accuracy: 0.6683 - val_loss: 1.5566 - learning_rate: 1.2500e-04
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - loss: 0.0046
# Epoch 28: val_accuracy improved from 0.85713 to 0.94145, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 94s 212ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9414 - val_loss: 0.2884 - learning_rate: 1.2500e-04
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9988 - loss: 0.0041
# Epoch 29: val_accuracy did not improve from 0.94145
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9389 - val_loss: 0.3094 - learning_rate: 1.2500e-04
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9991 - loss: 0.0030
# Epoch 30: val_accuracy improved from 0.94145 to 0.94613, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 202ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9461 - val_loss: 0.2777 - learning_rate: 1.2500e-04
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9992 - loss: 0.0022
# Epoch 31: val_accuracy did not improve from 0.94613
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 210ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 0.5204 - val_loss: 2.0170 - learning_rate: 1.2500e-04
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9987 - loss: 0.0058
# Epoch 32: val_accuracy did not improve from 0.94613
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 93s 208ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.9213 - val_loss: 0.3895 - learning_rate: 1.2500e-04
# Epoch 33/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9997 - loss: 0.0013
# Epoch 33: val_accuracy did not improve from 0.94613
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.4395 - val_loss: 2.9843 - learning_rate: 1.2500e-04
# Epoch 34/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - loss: 0.0056
# Epoch 34: val_accuracy did not improve from 0.94613
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 96s 215ms/step - accuracy: 0.9985 - loss: 0.0056 - val_accuracy: 0.7465 - val_loss: 1.1182 - learning_rate: 1.2500e-04
# Epoch 35/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9984 - loss: 0.0042
# Epoch 35: val_accuracy did not improve from 0.94613
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 204ms/step - accuracy: 0.9984 - loss: 0.0042 - val_accuracy: 0.8567 - val_loss: 0.7118 - learning_rate: 1.2500e-04
# Epoch 36/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9991 - loss: 0.0030
# Epoch 36: val_accuracy improved from 0.94613 to 0.94847, saving model to best_EfficientNetV2B0_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9485 - val_loss: 0.2900 - learning_rate: 6.2500e-05
# Epoch 37/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9997 - loss: 9.1097e-04
# Epoch 37: val_accuracy did not improve from 0.94847
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 206ms/step - accuracy: 0.9997 - loss: 9.1294e-04 - val_accuracy: 0.9303 - val_loss: 0.3810 - learning_rate: 6.2500e-05
# Epoch 38/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9995 - loss: 0.0014
# Epoch 38: val_accuracy did not improve from 0.94847
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 92s 208ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.1128 - val_loss: 6.0555 - learning_rate: 6.2500e-05
# Epoch 39/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9994 - loss: 0.0022
# Epoch 39: val_accuracy did not improve from 0.94847
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 91s 205ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.8462 - val_loss: 0.7719 - learning_rate: 6.2500e-05
# Epoch 40/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9997 - loss: 0.0017
# Epoch 40: val_accuracy did not improve from 0.94847
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 90s 201ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.8797 - val_loss: 0.5330 - learning_rate: 6.2500e-05
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Training completed!
# {"id":"7qrt06cP2VxF","time":1755976468,"expires":1756019668,"event":"message","topic":"model_complete","message":"efficientnetv2b0 Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 113s 286ms/step
# Test Loss: 0.2705
# Test Accuracy: 0.9480
# Precision: 0.9188
# Recall: 0.9280
# F1 Score: 0.9217
# Parameters: 7925627

# %%
model.save('densenet_final_model.keras')
model.save_weights('densenet_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["EfficientNetV2B0"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# !curl -d "Finished" ntfy.sh/model_complete
# Out:
# | Model            |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:-----------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | EfficientNetV2B0 |  7925627 |      0.2705 |      0.948 |      0.9188 |    0.928 | 0.9217 |
# {"id":"Ibo0uN8PJKEg","time":1755976630,"expires":1756019830,"event":"message","topic":"model_complete","message":"Finished"}
