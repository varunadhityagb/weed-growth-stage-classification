# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = Xception(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)


model = Model(inputs=base_model.input, outputs=output)


optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1760383507.826935      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 23,654,227
# Trainable parameters: 23,599,699

# %%
checkpoint_cb = ModelCheckpoint(
    "best_Xception_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Xception Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Xception Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Xception Starting training
# {"id":"i6NW17KCDKmc","time":1760383742,"expires":1760426942,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760383780.076135     116 service.cc:148] XLA service 0x792b7c0020c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760383780.076906     116 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1760383783.398618     116 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1760383793.130022     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383793.331536     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383794.386626     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383794.574276     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383795.475059     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383795.675542     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383796.095610     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383796.322158     116 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1760383804.466970     116 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 362/445 ━━━━━━━━━━━━━━━━━━━━ 20s 250ms/step - accuracy: 0.1192 - loss: 3.0565
# E0000 00:00:1760383901.913601     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383902.107174     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383902.693872     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383902.878835     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383903.400894     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383903.599853     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383904.008892     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1760383904.232758     118 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.1345 - loss: 2.9503
# Epoch 1: val_accuracy improved from -inf to 0.05010, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 269s 467ms/step - accuracy: 0.1347 - loss: 2.9491 - val_accuracy: 0.0501 - val_loss: 12.3037 - learning_rate: 0.0010
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.4420 - loss: 1.4743
# Epoch 2: val_accuracy improved from 0.05010 to 0.54111, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 337ms/step - accuracy: 0.4421 - loss: 1.4740 - val_accuracy: 0.5411 - val_loss: 1.4934 - learning_rate: 0.0010
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.6527 - loss: 0.9111
# Epoch 3: val_accuracy improved from 0.54111 to 0.71142, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 153s 344ms/step - accuracy: 0.6527 - loss: 0.9110 - val_accuracy: 0.7114 - val_loss: 0.7948 - learning_rate: 0.0010
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.7721 - loss: 0.6192
# Epoch 4: val_accuracy improved from 0.71142 to 0.73526, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.7721 - loss: 0.6191 - val_accuracy: 0.7353 - val_loss: 0.7432 - learning_rate: 0.0010
# Epoch 5/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8303 - loss: 0.4650
# Epoch 5: val_accuracy improved from 0.73526 to 0.78018, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.8303 - loss: 0.4650 - val_accuracy: 0.7802 - val_loss: 0.7309 - learning_rate: 0.0010
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8680 - loss: 0.3820
# Epoch 6: val_accuracy did not improve from 0.78018
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 335ms/step - accuracy: 0.8680 - loss: 0.3820 - val_accuracy: 0.7440 - val_loss: 0.8083 - learning_rate: 0.0010
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8965 - loss: 0.3133
# Epoch 7: val_accuracy improved from 0.78018 to 0.86039, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 153s 343ms/step - accuracy: 0.8965 - loss: 0.3133 - val_accuracy: 0.8604 - val_loss: 0.4594 - learning_rate: 0.0010
# Epoch 8/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.8947 - loss: 0.3101
# Epoch 8: val_accuracy did not improve from 0.86039
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 335ms/step - accuracy: 0.8947 - loss: 0.3101 - val_accuracy: 0.8069 - val_loss: 0.6325 - learning_rate: 0.0010
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9145 - loss: 0.2564
# Epoch 9: val_accuracy did not improve from 0.86039
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.9145 - loss: 0.2564 - val_accuracy: 0.8274 - val_loss: 0.5285 - learning_rate: 0.0010
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9259 - loss: 0.2331
# Epoch 10: val_accuracy improved from 0.86039 to 0.87512, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 337ms/step - accuracy: 0.9259 - loss: 0.2332 - val_accuracy: 0.8751 - val_loss: 0.3835 - learning_rate: 0.0010
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9407 - loss: 0.1887
# Epoch 11: val_accuracy did not improve from 0.87512
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9407 - loss: 0.1887 - val_accuracy: 0.7997 - val_loss: 0.6862 - learning_rate: 0.0010
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9326 - loss: 0.2093
# Epoch 12: val_accuracy did not improve from 0.87512
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 334ms/step - accuracy: 0.9326 - loss: 0.2092 - val_accuracy: 0.8454 - val_loss: 0.4803 - learning_rate: 0.0010
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9370 - loss: 0.1928
# Epoch 13: val_accuracy did not improve from 0.87512
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 337ms/step - accuracy: 0.9370 - loss: 0.1927 - val_accuracy: 0.8015 - val_loss: 0.8394 - learning_rate: 0.0010
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9483 - loss: 0.1643
# Epoch 14: val_accuracy improved from 0.87512 to 0.88197, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 332ms/step - accuracy: 0.9483 - loss: 0.1643 - val_accuracy: 0.8820 - val_loss: 0.4389 - learning_rate: 0.0010
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9557 - loss: 0.1469
# Epoch 15: val_accuracy did not improve from 0.88197
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 334ms/step - accuracy: 0.9557 - loss: 0.1469 - val_accuracy: 0.8174 - val_loss: 0.6377 - learning_rate: 0.0010
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9743 - loss: 0.0925
# Epoch 16: val_accuracy improved from 0.88197 to 0.93133, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 334ms/step - accuracy: 0.9743 - loss: 0.0925 - val_accuracy: 0.9313 - val_loss: 0.2484 - learning_rate: 5.0000e-04
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9853 - loss: 0.0447
# Epoch 17: val_accuracy did not improve from 0.93133
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9853 - loss: 0.0447 - val_accuracy: 0.9297 - val_loss: 0.2784 - learning_rate: 5.0000e-04
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9898 - loss: 0.0341
# Epoch 18: val_accuracy did not improve from 0.93133
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 338ms/step - accuracy: 0.9898 - loss: 0.0341 - val_accuracy: 0.9298 - val_loss: 0.3076 - learning_rate: 5.0000e-04
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9892 - loss: 0.0348
# Epoch 19: val_accuracy did not improve from 0.93133
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.9892 - loss: 0.0348 - val_accuracy: 0.9221 - val_loss: 0.2972 - learning_rate: 5.0000e-04
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9885 - loss: 0.0425
# Epoch 20: val_accuracy did not improve from 0.93133
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 332ms/step - accuracy: 0.9885 - loss: 0.0425 - val_accuracy: 0.9052 - val_loss: 0.4083 - learning_rate: 5.0000e-04
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9866 - loss: 0.0475
# Epoch 21: val_accuracy did not improve from 0.93133
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 336ms/step - accuracy: 0.9866 - loss: 0.0475 - val_accuracy: 0.9030 - val_loss: 0.3818 - learning_rate: 5.0000e-04
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9931 - loss: 0.0248
# Epoch 22: val_accuracy improved from 0.93133 to 0.94044, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.9931 - loss: 0.0247 - val_accuracy: 0.9404 - val_loss: 0.2470 - learning_rate: 2.5000e-04
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9980 - loss: 0.0080
# Epoch 23: val_accuracy improved from 0.94044 to 0.94396, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 336ms/step - accuracy: 0.9980 - loss: 0.0080 - val_accuracy: 0.9440 - val_loss: 0.2564 - learning_rate: 2.5000e-04
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9968 - loss: 0.0121
# Epoch 24: val_accuracy improved from 0.94396 to 0.94504, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 337ms/step - accuracy: 0.9968 - loss: 0.0121 - val_accuracy: 0.9450 - val_loss: 0.2541 - learning_rate: 2.5000e-04
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9982 - loss: 0.0058
# Epoch 25: val_accuracy did not improve from 0.94504
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9428 - val_loss: 0.3066 - learning_rate: 2.5000e-04
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9969 - loss: 0.0135
# Epoch 26: val_accuracy did not improve from 0.94504
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9969 - loss: 0.0135 - val_accuracy: 0.9352 - val_loss: 0.2987 - learning_rate: 2.5000e-04
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9961 - loss: 0.0133
# Epoch 27: val_accuracy did not improve from 0.94504
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 153s 343ms/step - accuracy: 0.9961 - loss: 0.0133 - val_accuracy: 0.9284 - val_loss: 0.3510 - learning_rate: 2.5000e-04
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9988 - loss: 0.0061
# Epoch 28: val_accuracy did not improve from 0.94504
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9988 - loss: 0.0061 - val_accuracy: 0.9413 - val_loss: 0.2763 - learning_rate: 1.2500e-04
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9994 - loss: 0.0032
# Epoch 29: val_accuracy improved from 0.94504 to 0.94688, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 339ms/step - accuracy: 0.9994 - loss: 0.0032 - val_accuracy: 0.9469 - val_loss: 0.2675 - learning_rate: 1.2500e-04
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9996 - loss: 0.0025
# Epoch 30: val_accuracy improved from 0.94688 to 0.95082, saving model to best_Xception_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 336ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.9508 - val_loss: 0.2605 - learning_rate: 1.2500e-04
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.9996 - loss: 0.0017
# Epoch 31: val_accuracy did not improve from 0.95082
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 331ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9486 - val_loss: 0.2761 - learning_rate: 1.2500e-04
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9995 - loss: 0.0039
# Epoch 32: val_accuracy improved from 0.95082 to 0.95199, saving model to best_Xception_model.h5
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 337ms/step - accuracy: 0.9995 - loss: 0.0039 - val_accuracy: 0.9520 - val_loss: 0.2659 - learning_rate: 1.2500e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Training completed!
# {"id":"m6sgdgml1PYH","time":1760388659,"expires":1760431859,"event":"message","topic":"model_complete","message":"Xception Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 36s 96ms/step
# Test Loss: 0.2521
# Test Accuracy: 0.9419
# Precision: 0.9128
# Recall: 0.9118
# F1 Score: 0.9079
# Parameters: 23654227

# %%
model.save('xception_final_model.keras')
model.save_weights('xception_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["Xception"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# !curl -d "Finished" ntfy.sh/model_complete
# Out:
# | Model    |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:---------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | Xception | 23654227 |      0.2521 |     0.9419 |      0.9128 |   0.9118 | 0.9079 |
# {"id":"sqNDsHlGIb2n","time":1760389105,"expires":1760432305,"event":"message","topic":"model_complete","message":"Finished"}
