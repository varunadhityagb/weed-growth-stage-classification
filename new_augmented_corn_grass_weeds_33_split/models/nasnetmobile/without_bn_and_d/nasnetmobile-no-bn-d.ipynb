# %%
import tensorflow as tf
# Out:
# 2025-10-14 03:16:48.084786: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760411808.283626      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760411808.335610      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)

train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = NASNetMobile(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR,
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1760411859.421725      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 6,046,655
# Trainable parameters: 6,009,917

# %%
checkpoint_cb = ModelCheckpoint(
    "best_NASNetMobile_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("NASNetMobile Starting training ")
get_ipython().system('curl -d "Train Start" ntfy.sh/model_complete')

# Train
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
get_ipython().system('curl -d "NASNetMobile Train Complete" ntfy.sh/model_complete')

with open('training_history.json', 'w') as f:
    json.dump(history.history, f)
# Out:
# NASNetMobile Starting training
# {"id":"gksdY6ZFA2m3","time":1760411932,"expires":1760455132,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760412118.549123     122 service.cc:148] XLA service 0x7956000036f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760412118.549998     122 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1760412135.758190     122 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1760412190.545381     122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.2520 - loss: 2.5080
# Epoch 1: val_accuracy improved from -inf to 0.08791, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 571s 706ms/step - accuracy: 0.2523 - loss: 2.5067 - val_accuracy: 0.0879 - val_loss: 103.2815 - learning_rate: 0.0010
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.6424 - loss: 1.0100
# Epoch 2: val_accuracy improved from 0.08791 to 0.09419, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 325ms/step - accuracy: 0.6425 - loss: 1.0097 - val_accuracy: 0.0942 - val_loss: 15.0649 - learning_rate: 0.0010
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7769 - loss: 0.6314
# Epoch 3: val_accuracy did not improve from 0.09419
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 317ms/step - accuracy: 0.7770 - loss: 0.6313 - val_accuracy: 0.0565 - val_loss: 9.2961 - learning_rate: 0.0010
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8310 - loss: 0.4892
# Epoch 4: val_accuracy did not improve from 0.09419
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 321ms/step - accuracy: 0.8310 - loss: 0.4893 - val_accuracy: 0.0330 - val_loss: 54.8564 - learning_rate: 0.0010
# Epoch 5/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8643 - loss: 0.3918
# Epoch 5: val_accuracy improved from 0.09419 to 0.12664, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 321ms/step - accuracy: 0.8643 - loss: 0.3918 - val_accuracy: 0.1266 - val_loss: 10.9273 - learning_rate: 0.0010
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8744 - loss: 0.3564
# Epoch 6: val_accuracy improved from 0.12664 to 0.17474, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 321ms/step - accuracy: 0.8744 - loss: 0.3564 - val_accuracy: 0.1747 - val_loss: 5.0697 - learning_rate: 0.0010
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8897 - loss: 0.3276
# Epoch 7: val_accuracy did not improve from 0.17474
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.8897 - loss: 0.3276 - val_accuracy: 0.1573 - val_loss: 6.5756 - learning_rate: 0.0010
# Epoch 8/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9136 - loss: 0.2589
# Epoch 8: val_accuracy did not improve from 0.17474
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 320ms/step - accuracy: 0.9136 - loss: 0.2589 - val_accuracy: 0.1131 - val_loss: 12.0506 - learning_rate: 0.0010
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9095 - loss: 0.2821
# Epoch 9: val_accuracy did not improve from 0.17474
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 322ms/step - accuracy: 0.9095 - loss: 0.2821 - val_accuracy: 0.1082 - val_loss: 8.8940 - learning_rate: 0.0010
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9245 - loss: 0.2304
# Epoch 10: val_accuracy improved from 0.17474 to 0.21255, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 320ms/step - accuracy: 0.9245 - loss: 0.2305 - val_accuracy: 0.2125 - val_loss: 5.0847 - learning_rate: 0.0010
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9175 - loss: 0.2665
# Epoch 11: val_accuracy improved from 0.21255 to 0.42074, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 147s 330ms/step - accuracy: 0.9175 - loss: 0.2665 - val_accuracy: 0.4207 - val_loss: 2.4566 - learning_rate: 0.0010
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9429 - loss: 0.1835
# Epoch 12: val_accuracy did not improve from 0.42074
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 317ms/step - accuracy: 0.9429 - loss: 0.1835 - val_accuracy: 0.2881 - val_loss: 7.4451 - learning_rate: 0.0010
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9435 - loss: 0.1816
# Epoch 13: val_accuracy did not improve from 0.42074
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.9435 - loss: 0.1816 - val_accuracy: 0.3302 - val_loss: 3.6203 - learning_rate: 0.0010
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9369 - loss: 0.1946
# Epoch 14: val_accuracy did not improve from 0.42074
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 142s 318ms/step - accuracy: 0.9369 - loss: 0.1946 - val_accuracy: 0.2667 - val_loss: 6.7391 - learning_rate: 0.0010
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9611 - loss: 0.1295
# Epoch 15: val_accuracy improved from 0.42074 to 0.55475, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 147s 329ms/step - accuracy: 0.9611 - loss: 0.1295 - val_accuracy: 0.5547 - val_loss: 2.1145 - learning_rate: 0.0010
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9546 - loss: 0.1593
# Epoch 16: val_accuracy did not improve from 0.55475
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 317ms/step - accuracy: 0.9545 - loss: 0.1593 - val_accuracy: 0.5517 - val_loss: 2.8251 - learning_rate: 0.0010
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9557 - loss: 0.1544
# Epoch 17: val_accuracy improved from 0.55475 to 0.66985, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 327ms/step - accuracy: 0.9558 - loss: 0.1544 - val_accuracy: 0.6698 - val_loss: 1.8926 - learning_rate: 0.0010
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9627 - loss: 0.1407
# Epoch 18: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 336ms/step - accuracy: 0.9627 - loss: 0.1407 - val_accuracy: 0.5240 - val_loss: 2.5248 - learning_rate: 0.0010
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9568 - loss: 0.1478
# Epoch 19: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 151s 338ms/step - accuracy: 0.9568 - loss: 0.1479 - val_accuracy: 0.4832 - val_loss: 2.6858 - learning_rate: 0.0010
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9573 - loss: 0.1461
# Epoch 20: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 332ms/step - accuracy: 0.9573 - loss: 0.1462 - val_accuracy: 0.6645 - val_loss: 1.3800 - learning_rate: 0.0010
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9624 - loss: 0.1259
# Epoch 21: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9624 - loss: 0.1259 - val_accuracy: 0.5946 - val_loss: 1.9416 - learning_rate: 0.0010
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9421 - loss: 0.1945
# Epoch 22: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 0.9422 - loss: 0.1944 - val_accuracy: 0.6352 - val_loss: 1.8898 - learning_rate: 0.0010
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9690 - loss: 0.1031
# Epoch 23: val_accuracy did not improve from 0.66985
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 147s 331ms/step - accuracy: 0.9690 - loss: 0.1032 - val_accuracy: 0.5706 - val_loss: 2.3090 - learning_rate: 0.0010
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9589 - loss: 0.1347
# Epoch 24: val_accuracy improved from 0.66985 to 0.76186, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 156s 349ms/step - accuracy: 0.9589 - loss: 0.1347 - val_accuracy: 0.7619 - val_loss: 1.0265 - learning_rate: 0.0010
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9694 - loss: 0.1029
# Epoch 25: val_accuracy did not improve from 0.76186
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 332ms/step - accuracy: 0.9694 - loss: 0.1029 - val_accuracy: 0.6754 - val_loss: 1.5358 - learning_rate: 0.0010
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9710 - loss: 0.1019
# Epoch 26: val_accuracy did not improve from 0.76186
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 336ms/step - accuracy: 0.9710 - loss: 0.1019 - val_accuracy: 0.6583 - val_loss: 1.5704 - learning_rate: 0.0010
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9664 - loss: 0.1167
# Epoch 27: val_accuracy did not improve from 0.76186
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 147s 331ms/step - accuracy: 0.9664 - loss: 0.1167 - val_accuracy: 0.6609 - val_loss: 1.8014 - learning_rate: 0.0010
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9706 - loss: 0.1052
# Epoch 28: val_accuracy did not improve from 0.76186
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 146s 329ms/step - accuracy: 0.9706 - loss: 0.1052 - val_accuracy: 0.7432 - val_loss: 1.0395 - learning_rate: 0.0010
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9799 - loss: 0.0739
# Epoch 29: val_accuracy did not improve from 0.76186
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 152s 342ms/step - accuracy: 0.9799 - loss: 0.0739 - val_accuracy: 0.7213 - val_loss: 1.4417 - learning_rate: 0.0010
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9831 - loss: 0.0622
# Epoch 30: val_accuracy improved from 0.76186 to 0.89143, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 150s 336ms/step - accuracy: 0.9831 - loss: 0.0621 - val_accuracy: 0.8914 - val_loss: 0.4960 - learning_rate: 5.0000e-04
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9913 - loss: 0.0298
# Epoch 31: val_accuracy did not improve from 0.89143
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 334ms/step - accuracy: 0.9913 - loss: 0.0298 - val_accuracy: 0.8876 - val_loss: 0.5069 - learning_rate: 5.0000e-04
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9936 - loss: 0.0228
# Epoch 32: val_accuracy improved from 0.89143 to 0.91418, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 326ms/step - accuracy: 0.9936 - loss: 0.0228 - val_accuracy: 0.9142 - val_loss: 0.4210 - learning_rate: 5.0000e-04
# Epoch 33/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9963 - loss: 0.0122
# Epoch 33: val_accuracy improved from 0.91418 to 0.91811, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 326ms/step - accuracy: 0.9963 - loss: 0.0122 - val_accuracy: 0.9181 - val_loss: 0.3837 - learning_rate: 5.0000e-04
# Epoch 34/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9976 - loss: 0.0121
# Epoch 34: val_accuracy did not improve from 0.91811
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 322ms/step - accuracy: 0.9976 - loss: 0.0121 - val_accuracy: 0.9044 - val_loss: 0.4542 - learning_rate: 5.0000e-04
# Epoch 35/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9929 - loss: 0.0313
# Epoch 35: val_accuracy did not improve from 0.91811
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 314ms/step - accuracy: 0.9929 - loss: 0.0313 - val_accuracy: 0.8780 - val_loss: 0.5396 - learning_rate: 5.0000e-04
# Epoch 36/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9906 - loss: 0.0367
# Epoch 36: val_accuracy did not improve from 0.91811
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 318ms/step - accuracy: 0.9906 - loss: 0.0367 - val_accuracy: 0.8513 - val_loss: 0.6551 - learning_rate: 5.0000e-04
# Epoch 37/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9922 - loss: 0.0250
# Epoch 37: val_accuracy did not improve from 0.91811
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 315ms/step - accuracy: 0.9922 - loss: 0.0251 - val_accuracy: 0.8480 - val_loss: 0.7608 - learning_rate: 5.0000e-04
# Epoch 38/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9941 - loss: 0.0207
# Epoch 38: val_accuracy did not improve from 0.91811
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 308ms/step - accuracy: 0.9941 - loss: 0.0207 - val_accuracy: 0.8643 - val_loss: 0.6841 - learning_rate: 5.0000e-04
# Epoch 39/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9969 - loss: 0.0108
# Epoch 39: val_accuracy improved from 0.91811 to 0.92221, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 315ms/step - accuracy: 0.9969 - loss: 0.0108 - val_accuracy: 0.9222 - val_loss: 0.3654 - learning_rate: 2.5000e-04
# Epoch 40/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9975 - loss: 0.0085
# Epoch 40: val_accuracy improved from 0.92221 to 0.92514, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 144s 324ms/step - accuracy: 0.9976 - loss: 0.0085 - val_accuracy: 0.9251 - val_loss: 0.3581 - learning_rate: 2.5000e-04
# Epoch 41/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 6.7997e-04
# Epoch 41: val_accuracy improved from 0.92514 to 0.93509, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 142s 320ms/step - accuracy: 1.0000 - loss: 6.7965e-04 - val_accuracy: 0.9351 - val_loss: 0.3258 - learning_rate: 2.5000e-04
# Epoch 42/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9989 - loss: 0.0043
# Epoch 42: val_accuracy did not improve from 0.93509
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 314ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 0.9336 - val_loss: 0.3450 - learning_rate: 2.5000e-04
# Epoch 43/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9982 - loss: 0.0082
# Epoch 43: val_accuracy did not improve from 0.93509
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 314ms/step - accuracy: 0.9982 - loss: 0.0082 - val_accuracy: 0.9026 - val_loss: 0.4771 - learning_rate: 2.5000e-04
# Epoch 44/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9972 - loss: 0.0130
# Epoch 44: val_accuracy did not improve from 0.93509
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 317ms/step - accuracy: 0.9972 - loss: 0.0130 - val_accuracy: 0.9104 - val_loss: 0.5153 - learning_rate: 2.5000e-04
# Epoch 45/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9974 - loss: 0.0096
# Epoch 45: val_accuracy did not improve from 0.93509
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 313ms/step - accuracy: 0.9974 - loss: 0.0096 - val_accuracy: 0.9130 - val_loss: 0.4789 - learning_rate: 2.5000e-04
# Epoch 46/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9994 - loss: 0.0024
# Epoch 46: val_accuracy did not improve from 0.93509
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 317ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9338 - val_loss: 0.3597 - learning_rate: 2.5000e-04
# Epoch 47/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9988 - loss: 0.0042
# Epoch 47: val_accuracy improved from 0.93509 to 0.93885, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 326ms/step - accuracy: 0.9988 - loss: 0.0042 - val_accuracy: 0.9389 - val_loss: 0.3175 - learning_rate: 1.2500e-04
# Epoch 48/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9997 - loss: 0.0013
# Epoch 48: val_accuracy improved from 0.93885 to 0.93902, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 322ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9390 - val_loss: 0.3312 - learning_rate: 1.2500e-04
# Epoch 49/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 2.8302e-04
# Epoch 49: val_accuracy improved from 0.93902 to 0.94672, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 148s 333ms/step - accuracy: 1.0000 - loss: 2.8328e-04 - val_accuracy: 0.9467 - val_loss: 0.2864 - learning_rate: 1.2500e-04
# Epoch 50/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9998 - loss: 4.7513e-04
# Epoch 50: val_accuracy did not improve from 0.94672
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.9998 - loss: 4.7595e-04 - val_accuracy: 0.9363 - val_loss: 0.3832 - learning_rate: 1.2500e-04
# Epoch 51/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 1.3599e-04
# Epoch 51: val_accuracy did not improve from 0.94672
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 146s 327ms/step - accuracy: 1.0000 - loss: 1.3595e-04 - val_accuracy: 0.9456 - val_loss: 0.3204 - learning_rate: 1.2500e-04
# Epoch 52/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 8.1184e-05
# Epoch 52: val_accuracy did not improve from 0.94672
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 145s 326ms/step - accuracy: 1.0000 - loss: 8.1157e-05 - val_accuracy: 0.9451 - val_loss: 0.3264 - learning_rate: 1.2500e-04
# Epoch 53/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 5.9999e-05
# Epoch 53: val_accuracy improved from 0.94672 to 0.94797, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 142s 320ms/step - accuracy: 1.0000 - loss: 5.9973e-05 - val_accuracy: 0.9480 - val_loss: 0.3150 - learning_rate: 1.2500e-04
# Epoch 54/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 4.5540e-05
# Epoch 54: val_accuracy improved from 0.94797 to 0.94906, saving model to best_NASNetMobile_model.h5
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 146s 328ms/step - accuracy: 1.0000 - loss: 4.5534e-05 - val_accuracy: 0.9491 - val_loss: 0.3143 - learning_rate: 1.2500e-04
# Epoch 55/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 6.9089e-05
# Epoch 55: val_accuracy improved from 0.94906 to 0.95082, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 335ms/step - accuracy: 1.0000 - loss: 6.9045e-05 - val_accuracy: 0.9508 - val_loss: 0.3130 - learning_rate: 6.2500e-05
# Epoch 56/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 1.0000 - loss: 4.4419e-05
# Epoch 56: val_accuracy improved from 0.95082 to 0.95366, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 149s 334ms/step - accuracy: 1.0000 - loss: 4.4426e-05 - val_accuracy: 0.9537 - val_loss: 0.3106 - learning_rate: 6.2500e-05
# Epoch 57/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9999 - loss: 2.9359e-04
# Epoch 57: val_accuracy did not improve from 0.95366
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.9999 - loss: 2.9412e-04 - val_accuracy: 0.9503 - val_loss: 0.3277 - learning_rate: 6.2500e-05
# Epoch 58/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 1.8555e-04
# Epoch 58: val_accuracy did not improve from 0.95366
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 313ms/step - accuracy: 1.0000 - loss: 1.8542e-04 - val_accuracy: 0.9534 - val_loss: 0.3214 - learning_rate: 6.2500e-05
# Epoch 59/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 4.0119e-05
# Epoch 59: val_accuracy did not improve from 0.95366
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 315ms/step - accuracy: 1.0000 - loss: 4.0106e-05 - val_accuracy: 0.9531 - val_loss: 0.3281 - learning_rate: 6.2500e-05
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 49.
# Training completed!
# {"id":"f1zSYkOBqOwb","time":1760420878,"expires":1760464078,"event":"message","topic":"model_complete","message":"NASNetMobile Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Parameters: {num_params}")

plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 157s 384ms/step
# Test Loss: 0.3103
# Test Accuracy: 0.9435
# Precision: 0.8994
# Recall: 0.9310
# F1 Score: 0.9120
# Parameters: 6046655

# %%
model.save('nasnetmobile_final_model.keras')
model.save_weights('nasnetmobile_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["NASNetMobile"],
    "Params": [num_params],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))

import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

get_ipython().system('curl -d "Finished" ntfy.sh/model_complete')
# Out:
# | Model        |   Params |   Test Loss |   Test Acc |   Precision |   Recall |    F1 |
# |:-------------|---------:|------------:|-----------:|------------:|---------:|------:|
# | NASNetMobile |  6046655 |      0.3103 |     0.9435 |      0.8994 |    0.931 | 0.912 |
# {"id":"yf8qXzFTFwRt","time":1760421102,"expires":1760464302,"event":"message","topic":"model_complete","message":"Finished"}
