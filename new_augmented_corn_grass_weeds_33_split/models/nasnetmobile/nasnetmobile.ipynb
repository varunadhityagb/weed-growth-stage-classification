# %%
import tensorflow as tf
# Out:
# 2025-10-13 16:38:32.813770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760373512.999833      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760373513.057228      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 100
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)

train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = NASNetMobile(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR,
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1760373531.653326      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 6,053,823
# Trainable parameters: 6,013,501

# %%
checkpoint_cb = ModelCheckpoint(
    "best_NASNetMobile_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("NASNetMobile Starting training ")
get_ipython().system('curl -d "Train Start" ntfy.sh/model_complete')

# Train
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
get_ipython().system('curl -d "NASNetMobile Train Complete" ntfy.sh/model_complete')

with open('training_history.json', 'w') as f:
    json.dump(history.history, f)
# Out:
# NASNetMobile Starting training
# {"id":"W4g6vF9VgTQX","time":1760373537,"expires":1760416737,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760373713.098251     115 service.cc:148] XLA service 0x78969c002610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760373713.099147     115 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1760373729.477933     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1760373785.269961     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.1647 - loss: 3.1002
# Epoch 1: val_accuracy improved from -inf to 0.02509, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 526s 629ms/step - accuracy: 0.1649 - loss: 3.0987 - val_accuracy: 0.0251 - val_loss: 14.2631 - learning_rate: 0.0010
# Epoch 2/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5192 - loss: 1.3621
# Epoch 2: val_accuracy improved from 0.02509 to 0.04492, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 315ms/step - accuracy: 0.5193 - loss: 1.3617 - val_accuracy: 0.0449 - val_loss: 8.9505 - learning_rate: 0.0010
# Epoch 3/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.6881 - loss: 0.8677
# Epoch 3: val_accuracy improved from 0.04492 to 0.16729, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 313ms/step - accuracy: 0.6881 - loss: 0.8676 - val_accuracy: 0.1673 - val_loss: 5.6865 - learning_rate: 0.0010
# Epoch 4/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7627 - loss: 0.6570
# Epoch 4: val_accuracy did not improve from 0.16729
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 313ms/step - accuracy: 0.7627 - loss: 0.6569 - val_accuracy: 0.1461 - val_loss: 5.7612 - learning_rate: 0.0010
# Epoch 5/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8168 - loss: 0.5249
# Epoch 5: val_accuracy did not improve from 0.16729
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 318ms/step - accuracy: 0.8168 - loss: 0.5249 - val_accuracy: 0.1659 - val_loss: 7.6468 - learning_rate: 0.0010
# Epoch 6/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8420 - loss: 0.4482
# Epoch 6: val_accuracy improved from 0.16729 to 0.26048, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 143s 322ms/step - accuracy: 0.8420 - loss: 0.4482 - val_accuracy: 0.2605 - val_loss: 5.4922 - learning_rate: 0.0010
# Epoch 7/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8707 - loss: 0.3849
# Epoch 7: val_accuracy did not improve from 0.26048
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 309ms/step - accuracy: 0.8707 - loss: 0.3849 - val_accuracy: 0.2069 - val_loss: 6.9552 - learning_rate: 0.0010
# Epoch 8/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8888 - loss: 0.3332
# Epoch 8: val_accuracy did not improve from 0.26048
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 305ms/step - accuracy: 0.8888 - loss: 0.3332 - val_accuracy: 0.1506 - val_loss: 6.9299 - learning_rate: 0.0010
# Epoch 9/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8855 - loss: 0.3514
# Epoch 9: val_accuracy did not improve from 0.26048
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 305ms/step - accuracy: 0.8855 - loss: 0.3513 - val_accuracy: 0.1180 - val_loss: 7.6275 - learning_rate: 0.0010
# Epoch 10/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9034 - loss: 0.2884
# Epoch 10: val_accuracy improved from 0.26048 to 0.33467, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 142s 318ms/step - accuracy: 0.9034 - loss: 0.2884 - val_accuracy: 0.3347 - val_loss: 3.5145 - learning_rate: 0.0010
# Epoch 11/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9068 - loss: 0.2810
# Epoch 11: val_accuracy improved from 0.33467 to 0.34287, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9068 - loss: 0.2809 - val_accuracy: 0.3429 - val_loss: 3.6411 - learning_rate: 0.0010
# Epoch 12/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9164 - loss: 0.2621
# Epoch 12: val_accuracy did not improve from 0.34287
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 304ms/step - accuracy: 0.9164 - loss: 0.2621 - val_accuracy: 0.2601 - val_loss: 5.3940 - learning_rate: 0.0010
# Epoch 13/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9230 - loss: 0.2394
# Epoch 13: val_accuracy improved from 0.34287 to 0.41907, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.9230 - loss: 0.2394 - val_accuracy: 0.4191 - val_loss: 2.8672 - learning_rate: 0.0010
# Epoch 14/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9387 - loss: 0.1989
# Epoch 14: val_accuracy did not improve from 0.41907
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 304ms/step - accuracy: 0.9387 - loss: 0.1989 - val_accuracy: 0.3403 - val_loss: 3.9506 - learning_rate: 0.0010
# Epoch 15/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9376 - loss: 0.2037
# Epoch 15: val_accuracy did not improve from 0.41907
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 308ms/step - accuracy: 0.9376 - loss: 0.2038 - val_accuracy: 0.2754 - val_loss: 4.5514 - learning_rate: 0.0010
# Epoch 16/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9358 - loss: 0.2127
# Epoch 16: val_accuracy did not improve from 0.41907
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 307ms/step - accuracy: 0.9358 - loss: 0.2127 - val_accuracy: 0.3465 - val_loss: 4.3910 - learning_rate: 0.0010
# Epoch 17/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9469 - loss: 0.1647
# Epoch 17: val_accuracy improved from 0.41907 to 0.55441, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 312ms/step - accuracy: 0.9469 - loss: 0.1647 - val_accuracy: 0.5544 - val_loss: 2.2917 - learning_rate: 0.0010
# Epoch 18/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9476 - loss: 0.1747
# Epoch 18: val_accuracy did not improve from 0.55441
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 305ms/step - accuracy: 0.9476 - loss: 0.1747 - val_accuracy: 0.4918 - val_loss: 2.6168 - learning_rate: 0.0010
# Epoch 19/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9556 - loss: 0.1398
# Epoch 19: val_accuracy did not improve from 0.55441
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9556 - loss: 0.1399 - val_accuracy: 0.4738 - val_loss: 3.7887 - learning_rate: 0.0010
# Epoch 20/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9483 - loss: 0.1644
# Epoch 20: val_accuracy did not improve from 0.55441
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 134s 302ms/step - accuracy: 0.9483 - loss: 0.1644 - val_accuracy: 0.4023 - val_loss: 4.1304 - learning_rate: 0.0010
# Epoch 21/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9565 - loss: 0.1496
# Epoch 21: val_accuracy did not improve from 0.55441
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9565 - loss: 0.1495 - val_accuracy: 0.4049 - val_loss: 3.7892 - learning_rate: 0.0010
# Epoch 22/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9600 - loss: 0.1406
# Epoch 22: val_accuracy did not improve from 0.55441
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 306ms/step - accuracy: 0.9600 - loss: 0.1406 - val_accuracy: 0.4893 - val_loss: 3.0433 - learning_rate: 0.0010
# Epoch 23/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9801 - loss: 0.0716
# Epoch 23: val_accuracy improved from 0.55441 to 0.80736, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9801 - loss: 0.0716 - val_accuracy: 0.8074 - val_loss: 0.8155 - learning_rate: 5.0000e-04
# Epoch 24/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9905 - loss: 0.0331
# Epoch 24: val_accuracy improved from 0.80736 to 0.83881, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 312ms/step - accuracy: 0.9905 - loss: 0.0331 - val_accuracy: 0.8388 - val_loss: 0.7157 - learning_rate: 5.0000e-04
# Epoch 25/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9896 - loss: 0.0348
# Epoch 25: val_accuracy did not improve from 0.83881
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 309ms/step - accuracy: 0.9896 - loss: 0.0348 - val_accuracy: 0.8332 - val_loss: 0.8227 - learning_rate: 5.0000e-04
# Epoch 26/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9841 - loss: 0.0564
# Epoch 26: val_accuracy improved from 0.83881 to 0.87386, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 316ms/step - accuracy: 0.9841 - loss: 0.0564 - val_accuracy: 0.8739 - val_loss: 0.6284 - learning_rate: 5.0000e-04
# Epoch 27/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9883 - loss: 0.0435
# Epoch 27: val_accuracy improved from 0.87386 to 0.87687, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 141s 316ms/step - accuracy: 0.9883 - loss: 0.0436 - val_accuracy: 0.8769 - val_loss: 0.5628 - learning_rate: 5.0000e-04
# Epoch 28/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9860 - loss: 0.0526
# Epoch 28: val_accuracy improved from 0.87687 to 0.90632, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 139s 311ms/step - accuracy: 0.9860 - loss: 0.0526 - val_accuracy: 0.9063 - val_loss: 0.4091 - learning_rate: 5.0000e-04
# Epoch 29/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9925 - loss: 0.0298
# Epoch 29: val_accuracy did not improve from 0.90632
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 308ms/step - accuracy: 0.9925 - loss: 0.0298 - val_accuracy: 0.8744 - val_loss: 0.5373 - learning_rate: 5.0000e-04
# Epoch 30/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9824 - loss: 0.0691
# Epoch 30: val_accuracy did not improve from 0.90632
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 306ms/step - accuracy: 0.9824 - loss: 0.0691 - val_accuracy: 0.7587 - val_loss: 1.2230 - learning_rate: 5.0000e-04
# Epoch 31/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9862 - loss: 0.0483
# Epoch 31: val_accuracy did not improve from 0.90632
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9862 - loss: 0.0483 - val_accuracy: 0.9004 - val_loss: 0.4477 - learning_rate: 5.0000e-04
# Epoch 32/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9884 - loss: 0.0415
# Epoch 32: val_accuracy did not improve from 0.90632
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 306ms/step - accuracy: 0.9884 - loss: 0.0415 - val_accuracy: 0.8857 - val_loss: 0.5252 - learning_rate: 5.0000e-04
# Epoch 33/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9884 - loss: 0.0486
# Epoch 33: val_accuracy improved from 0.90632 to 0.91041, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 307ms/step - accuracy: 0.9884 - loss: 0.0486 - val_accuracy: 0.9104 - val_loss: 0.3776 - learning_rate: 5.0000e-04
# Epoch 34/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9906 - loss: 0.0354
# Epoch 34: val_accuracy did not improve from 0.91041
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 304ms/step - accuracy: 0.9906 - loss: 0.0354 - val_accuracy: 0.8555 - val_loss: 0.6697 - learning_rate: 5.0000e-04
# Epoch 35/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9903 - loss: 0.0387
# Epoch 35: val_accuracy did not improve from 0.91041
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 302ms/step - accuracy: 0.9903 - loss: 0.0387 - val_accuracy: 0.8814 - val_loss: 0.5232 - learning_rate: 5.0000e-04
# Epoch 36/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9874 - loss: 0.0513
# Epoch 36: val_accuracy did not improve from 0.91041
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 307ms/step - accuracy: 0.9874 - loss: 0.0512 - val_accuracy: 0.8336 - val_loss: 0.7092 - learning_rate: 5.0000e-04
# Epoch 37/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9917 - loss: 0.0342
# Epoch 37: val_accuracy did not improve from 0.91041
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 140s 314ms/step - accuracy: 0.9917 - loss: 0.0342 - val_accuracy: 0.8144 - val_loss: 0.9303 - learning_rate: 5.0000e-04
# Epoch 38/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9849 - loss: 0.0553
# Epoch 38: val_accuracy did not improve from 0.91041
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 134s 302ms/step - accuracy: 0.9849 - loss: 0.0553 - val_accuracy: 0.7949 - val_loss: 0.9645 - learning_rate: 5.0000e-04
# Epoch 39/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9914 - loss: 0.0317
# Epoch 39: val_accuracy did not improve from 0.91041
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 134s 300ms/step - accuracy: 0.9914 - loss: 0.0317 - val_accuracy: 0.9000 - val_loss: 0.4339 - learning_rate: 2.5000e-04
# Epoch 40/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9991 - loss: 0.0064
# Epoch 40: val_accuracy improved from 0.91041 to 0.91987, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9991 - loss: 0.0064 - val_accuracy: 0.9199 - val_loss: 0.3618 - learning_rate: 2.5000e-04
# Epoch 41/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9984 - loss: 0.0048
# Epoch 41: val_accuracy did not improve from 0.91987
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 305ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9171 - val_loss: 0.3986 - learning_rate: 2.5000e-04
# Epoch 42/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9975 - loss: 0.0113
# Epoch 42: val_accuracy improved from 0.91987 to 0.93609, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 311ms/step - accuracy: 0.9975 - loss: 0.0113 - val_accuracy: 0.9361 - val_loss: 0.2907 - learning_rate: 2.5000e-04
# Epoch 43/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9974 - loss: 0.0098
# Epoch 43: val_accuracy did not improve from 0.93609
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 302ms/step - accuracy: 0.9974 - loss: 0.0098 - val_accuracy: 0.9352 - val_loss: 0.3071 - learning_rate: 2.5000e-04
# Epoch 44/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9983 - loss: 0.0089
# Epoch 44: val_accuracy did not improve from 0.93609
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 133s 300ms/step - accuracy: 0.9983 - loss: 0.0089 - val_accuracy: 0.9271 - val_loss: 0.3545 - learning_rate: 2.5000e-04
# Epoch 45/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9972 - loss: 0.0130
# Epoch 45: val_accuracy did not improve from 0.93609
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 310ms/step - accuracy: 0.9972 - loss: 0.0130 - val_accuracy: 0.9341 - val_loss: 0.3250 - learning_rate: 2.5000e-04
# Epoch 46/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9966 - loss: 0.0151
# Epoch 46: val_accuracy did not improve from 0.93609
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 303ms/step - accuracy: 0.9966 - loss: 0.0151 - val_accuracy: 0.9296 - val_loss: 0.3556 - learning_rate: 2.5000e-04
# Epoch 47/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9953 - loss: 0.0159
# Epoch 47: val_accuracy did not improve from 0.93609
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 134s 300ms/step - accuracy: 0.9953 - loss: 0.0159 - val_accuracy: 0.9335 - val_loss: 0.3110 - learning_rate: 2.5000e-04
# Epoch 48/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9983 - loss: 0.0063
# Epoch 48: val_accuracy improved from 0.93609 to 0.94036, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 136s 305ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9404 - val_loss: 0.2870 - learning_rate: 1.2500e-04
# Epoch 49/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9992 - loss: 0.0048
# Epoch 49: val_accuracy did not improve from 0.94036
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 133s 299ms/step - accuracy: 0.9992 - loss: 0.0048 - val_accuracy: 0.9375 - val_loss: 0.3018 - learning_rate: 1.2500e-04
# Epoch 50/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9995 - loss: 0.0023
# Epoch 50: val_accuracy improved from 0.94036 to 0.94964, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 138s 311ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9496 - val_loss: 0.2551 - learning_rate: 1.2500e-04
# Epoch 51/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9998 - loss: 0.0011
# Epoch 51: val_accuracy improved from 0.94964 to 0.95257, saving model to best_NASNetMobile_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 137s 307ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9526 - val_loss: 0.2506 - learning_rate: 1.2500e-04
# Epoch 52/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9990 - loss: 0.0034
# Epoch 52: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 132s 297ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9404 - val_loss: 0.3264 - learning_rate: 1.2500e-04
# Epoch 53/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9987 - loss: 0.0047
# Epoch 53: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 304ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9362 - val_loss: 0.3445 - learning_rate: 1.2500e-04
# Epoch 54/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9995 - loss: 0.0038
# Epoch 54: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 302ms/step - accuracy: 0.9995 - loss: 0.0038 - val_accuracy: 0.9357 - val_loss: 0.3458 - learning_rate: 1.2500e-04
# Epoch 55/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9987 - loss: 0.0037
# Epoch 55: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 303ms/step - accuracy: 0.9987 - loss: 0.0037 - val_accuracy: 0.9419 - val_loss: 0.3241 - learning_rate: 1.2500e-04
# Epoch 56/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9995 - loss: 0.0029
# Epoch 56: val_accuracy did not improve from 0.95257
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 132s 297ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9479 - val_loss: 0.2847 - learning_rate: 1.2500e-04
# Epoch 57/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9995 - loss: 0.0024
# Epoch 57: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 133s 300ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9473 - val_loss: 0.2863 - learning_rate: 6.2500e-05
# Epoch 58/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9999 - loss: 8.4388e-04
# Epoch 58: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 132s 298ms/step - accuracy: 0.9999 - loss: 8.4501e-04 - val_accuracy: 0.9486 - val_loss: 0.2809 - learning_rate: 6.2500e-05
# Epoch 59/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9998 - loss: 0.0019
# Epoch 59: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 134s 301ms/step - accuracy: 0.9998 - loss: 0.0019 - val_accuracy: 0.9471 - val_loss: 0.2919 - learning_rate: 6.2500e-05
# Epoch 60/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9997 - loss: 0.0017
# Epoch 60: val_accuracy did not improve from 0.95257
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 133s 300ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9461 - val_loss: 0.3085 - learning_rate: 6.2500e-05
# Epoch 61/100
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9999 - loss: 8.9952e-04
# Epoch 61: val_accuracy did not improve from 0.95257
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 135s 302ms/step - accuracy: 0.9999 - loss: 8.9999e-04 - val_accuracy: 0.9475 - val_loss: 0.3048 - learning_rate: 6.2500e-05
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 51.
# Training completed!
# {"id":"usr8taFknqku","time":1760382267,"expires":1760425467,"event":"message","topic":"model_complete","message":"NASNetMobile Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Parameters: {num_params}")

plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 138s 326ms/step
# Test Loss: 0.2790
# Test Accuracy: 0.9492
# Precision: 0.9083
# Recall: 0.9379
# F1 Score: 0.9197
# Parameters: 6053823

# %%
model.save('nasnetmobile_final_model.keras')
model.save_weights('nasnetmobile_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["NASNetMobile"],
    "Params": [num_params],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))

import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

get_ipython().system('curl -d "Finished" ntfy.sh/model_complete')
# Out:
# | Model        |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:-------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | NASNetMobile |  6053823 |       0.279 |     0.9492 |      0.9083 |   0.9379 | 0.9197 |
# {"id":"SFYxMttxvn8G","time":1760382460,"expires":1760425660,"event":"message","topic":"model_complete","message":"Finished"}
