# %%
import tensorflow as tf

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 50
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-new-aug-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = ResNet50(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

base_model.trainable = True

x = GlobalAveragePooling2D()(base_model.output)

x = Dense(1024, activation='relu')(x)

x = Dense(512, activation='relu')(x)

x = Dense(256, activation='relu')(x)

x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1755973389.592695      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 26,380,459
# Trainable parameters: 26,327,339

# %%
checkpoint_cb = ModelCheckpoint(
    "best_resnet50_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr]

print("Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Train Complete" ntfy.sh/model_complete

with open('training_history.json', 'w') as f:
    json.dump(history.history,f)
# Out:
# Starting training
# {"id":"9rGLdkvSEJCw","time":1755973394,"expires":1756016594,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755973448.547882     115 service.cc:148] XLA service 0x7844e4002770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755973448.548686     115 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1755973453.654994     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/445 ━━━━━━━━━━━━━━━━━━━━ 9:50:27 80s/step - accuracy: 0.0312 - loss: 3.8369
# I0000 00:00:1755973474.419059     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.1970 - loss: 2.7847
# Epoch 1: val_accuracy improved from -inf to 0.04032, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 282s 455ms/step - accuracy: 0.1973 - loss: 2.7834 - val_accuracy: 0.0403 - val_loss: 4.2893 - learning_rate: 0.0010
# Epoch 2/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5386 - loss: 1.2716
# Epoch 2: val_accuracy improved from 0.04032 to 0.21790, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.5386 - loss: 1.2714 - val_accuracy: 0.2179 - val_loss: 3.3106 - learning_rate: 0.0010
# Epoch 3/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7050 - loss: 0.7963
# Epoch 3: val_accuracy improved from 0.21790 to 0.65379, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.7050 - loss: 0.7962 - val_accuracy: 0.6538 - val_loss: 0.9986 - learning_rate: 0.0010
# Epoch 4/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7777 - loss: 0.6035
# Epoch 4: val_accuracy improved from 0.65379 to 0.73199, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.7777 - loss: 0.6034 - val_accuracy: 0.7320 - val_loss: 0.7766 - learning_rate: 0.0010
# Epoch 5/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8412 - loss: 0.4400
# Epoch 5: val_accuracy did not improve from 0.73199
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 260ms/step - accuracy: 0.8412 - loss: 0.4401 - val_accuracy: 0.7111 - val_loss: 0.8960 - learning_rate: 0.0010
# Epoch 6/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8649 - loss: 0.3843
# Epoch 6: val_accuracy did not improve from 0.73199
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.8649 - loss: 0.3843 - val_accuracy: 0.6668 - val_loss: 1.0347 - learning_rate: 0.0010
# Epoch 7/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8879 - loss: 0.3173
# Epoch 7: val_accuracy did not improve from 0.73199
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 248ms/step - accuracy: 0.8879 - loss: 0.3173 - val_accuracy: 0.7102 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 8/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9152 - loss: 0.2580
# Epoch 8: val_accuracy improved from 0.73199 to 0.81389, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.9152 - loss: 0.2581 - val_accuracy: 0.8139 - val_loss: 0.6147 - learning_rate: 0.0010
# Epoch 9/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9107 - loss: 0.2547
# Epoch 9: val_accuracy improved from 0.81389 to 0.82409, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9107 - loss: 0.2547 - val_accuracy: 0.8241 - val_loss: 0.5240 - learning_rate: 0.0010
# Epoch 10/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9228 - loss: 0.2308
# Epoch 10: val_accuracy did not improve from 0.82409
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9228 - loss: 0.2308 - val_accuracy: 0.7951 - val_loss: 0.6906 - learning_rate: 0.0010
# Epoch 11/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9259 - loss: 0.2168
# Epoch 11: val_accuracy improved from 0.82409 to 0.83413, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9259 - loss: 0.2168 - val_accuracy: 0.8341 - val_loss: 0.5284 - learning_rate: 0.0010
# Epoch 12/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9484 - loss: 0.1552
# Epoch 12: val_accuracy did not improve from 0.83413
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 248ms/step - accuracy: 0.9484 - loss: 0.1553 - val_accuracy: 0.7615 - val_loss: 0.8126 - learning_rate: 0.0010
# Epoch 13/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9410 - loss: 0.1888
# Epoch 13: val_accuracy did not improve from 0.83413
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 248ms/step - accuracy: 0.9410 - loss: 0.1887 - val_accuracy: 0.8317 - val_loss: 0.5424 - learning_rate: 0.0010
# Epoch 14/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9557 - loss: 0.1366
# Epoch 14: val_accuracy did not improve from 0.83413
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9557 - loss: 0.1366 - val_accuracy: 0.7850 - val_loss: 0.7491 - learning_rate: 0.0010
# Epoch 15/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9745 - loss: 0.0840
# Epoch 15: val_accuracy improved from 0.83413 to 0.90171, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9745 - loss: 0.0839 - val_accuracy: 0.9017 - val_loss: 0.3422 - learning_rate: 5.0000e-04
# Epoch 16/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9882 - loss: 0.0390
# Epoch 16: val_accuracy improved from 0.90171 to 0.90899, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 260ms/step - accuracy: 0.9882 - loss: 0.0390 - val_accuracy: 0.9090 - val_loss: 0.3583 - learning_rate: 5.0000e-04
# Epoch 17/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9906 - loss: 0.0292
# Epoch 17: val_accuracy did not improve from 0.90899
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 247ms/step - accuracy: 0.9906 - loss: 0.0292 - val_accuracy: 0.8569 - val_loss: 0.5824 - learning_rate: 5.0000e-04
# Epoch 18/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9882 - loss: 0.0350
# Epoch 18: val_accuracy did not improve from 0.90899
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9882 - loss: 0.0350 - val_accuracy: 0.9012 - val_loss: 0.4191 - learning_rate: 5.0000e-04
# Epoch 19/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9856 - loss: 0.0464
# Epoch 19: val_accuracy did not improve from 0.90899
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 247ms/step - accuracy: 0.9856 - loss: 0.0464 - val_accuracy: 0.9087 - val_loss: 0.3634 - learning_rate: 5.0000e-04
# Epoch 20/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9876 - loss: 0.0432
# Epoch 20: val_accuracy did not improve from 0.90899
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 248ms/step - accuracy: 0.9876 - loss: 0.0433 - val_accuracy: 0.8807 - val_loss: 0.4373 - learning_rate: 5.0000e-04
# Epoch 21/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9933 - loss: 0.0261
# Epoch 21: val_accuracy improved from 0.90899 to 0.92831, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 116s 260ms/step - accuracy: 0.9933 - loss: 0.0260 - val_accuracy: 0.9283 - val_loss: 0.2819 - learning_rate: 2.5000e-04
# Epoch 22/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9982 - loss: 0.0054
# Epoch 22: val_accuracy improved from 0.92831 to 0.93325, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9332 - val_loss: 0.2866 - learning_rate: 2.5000e-04
# Epoch 23/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9996 - loss: 0.0021
# Epoch 23: val_accuracy improved from 0.93325 to 0.93726, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.9373 - val_loss: 0.2886 - learning_rate: 2.5000e-04
# Epoch 24/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9994 - loss: 0.0019
# Epoch 24: val_accuracy did not improve from 0.93726
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9061 - val_loss: 0.4751 - learning_rate: 2.5000e-04
# Epoch 25/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9943 - loss: 0.0184
# Epoch 25: val_accuracy did not improve from 0.93726
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9943 - loss: 0.0184 - val_accuracy: 0.9159 - val_loss: 0.3716 - learning_rate: 2.5000e-04
# Epoch 26/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9964 - loss: 0.0121
# Epoch 26: val_accuracy did not improve from 0.93726
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 259ms/step - accuracy: 0.9964 - loss: 0.0121 - val_accuracy: 0.9266 - val_loss: 0.3441 - learning_rate: 2.5000e-04
# Epoch 27/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9986 - loss: 0.0060
# Epoch 27: val_accuracy did not improve from 0.93726
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9986 - loss: 0.0060 - val_accuracy: 0.9363 - val_loss: 0.3062 - learning_rate: 1.2500e-04
# Epoch 28/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9998 - loss: 0.0014
# Epoch 28: val_accuracy improved from 0.93726 to 0.94178, saving model to best_resnet50_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 255ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9418 - val_loss: 0.2862 - learning_rate: 1.2500e-04
# Epoch 29/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9998 - loss: 5.6235e-04
# Epoch 29: val_accuracy did not improve from 0.94178
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 110s 248ms/step - accuracy: 0.9998 - loss: 5.6267e-04 - val_accuracy: 0.9417 - val_loss: 0.3019 - learning_rate: 1.2500e-04
# Epoch 30/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9996 - loss: 0.0014
# Epoch 30: val_accuracy did not improve from 0.94178
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9333 - val_loss: 0.3300 - learning_rate: 1.2500e-04
# Epoch 31/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9986 - loss: 0.0041
# Epoch 31: val_accuracy did not improve from 0.94178
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9986 - loss: 0.0041 - val_accuracy: 0.9357 - val_loss: 0.3208 - learning_rate: 1.2500e-04
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Training completed!
# {"id":"iVKharygkiEJ","time":1755977041,"expires":1756020241,"event":"message","topic":"model_complete","message":"Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 84s 210ms/step
# Test Loss: 0.2809
# Test Accuracy: 0.9299
# Precision: 0.8972
# Recall: 0.8765
# F1 Score: 0.8831
# Parameters: 26380459

# %%
model.save('resnet50_final_model.keras')
model.save_weights('resnet50_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["ResNet50"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()
# Out:
# | Model    |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:---------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | ResNet50 | 26380459 |      0.2809 |     0.9299 |      0.8972 |   0.8765 | 0.8831 |
