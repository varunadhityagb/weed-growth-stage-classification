# %%
import tensorflow as tf
# Out:
# 2025-08-11 09:25:18.398470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754904318.608096      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754904318.676863      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
assert tf.config.list_physical_devices('GPU'), "No GPU detected: Check your Kaggle environment settings."
# Out:
# Num GPUs Available: 1

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
# from keras_flops import get_flops


IMG_SIZE = (224, 224)  # Adjust as needed
BATCH_SIZE = 32
DROPOUT_RATE = 0.3
INITIAL_LR = 0.001
EPOCHS = 50
SEED = 42

train_dir = '/kaggle/input/cwd30-corn-grass-weeds-split-33/data_final_split/train'
val_dir = '/kaggle/input/cwd30-corn-grass-weeds-split-33/data_final_split/val'
test_dir = '/kaggle/input/cwd30-corn-grass-weeds-split-33/data_final_split/test'

datagen_args = dict(rescale=1./255)
train_gen = ImageDataGenerator(**datagen_args)
val_gen = ImageDataGenerator(**datagen_args)
test_gen = ImageDataGenerator(**datagen_args)
train_flow = train_gen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True, seed=SEED)
val_flow = val_gen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_flow = test_gen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
num_classes = train_flow.num_classes
# Out:
# Found 14219 images belonging to 43 classes.
# Found 11955 images belonging to 43 classes.
# Found 11958 images belonging to 43 classes.

# %%
base_model = DenseNet121(
    include_top=False, 
    weights='imagenet', 
    input_shape=IMG_SIZE + (3,)
)

# Keep base model trainable (as per assignment requirement)
base_model.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)

x = Dense(128, activation='relu')(x)

output = Dense(num_classes, activation='softmax')(x)

# Create the model
model = Model(inputs=base_model.input, outputs=output)

# Compile model
optimizer = tf.keras.optimizers.AdamW(
    learning_rate=INITIAL_LR, 
    weight_decay=0.01
)

print("Compiling model...")
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# I0000 00:00:1754904339.542918      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...

# %%
print("\nModel Summary:")
print(f"Total parameters: {model.count_params():,}")
print(f"Trainable parameters: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
# Out:
# Model Summary:
# Total parameters: 8,788,843
# Trainable parameters: 8,701,611

# %%
checkpoint_cb = ModelCheckpoint(
    "best_densenet_model.h5",
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=10, 
    restore_best_weights=True,
    min_delta=0.001,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb]

print("Starting training ")
# !curl -d "Train Start" ntfy.sh/model_complete

# Train the whole model on your dataset
history = model.fit(
    train_flow,
    epochs=EPOCHS,
    validation_data=val_flow,
    callbacks=callbacks,
    verbose=1
)

print("Training completed!")
# !curl -d "Train Complete" ntfy.sh/model_complete
# Out:
# Starting training
# {"id":"mfTKbk0N2gm5","time":1754904343,"expires":1754947543,"event":"message","topic":"model_complete","message":"Train Start"}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754904438.547241     118 service.cc:148] XLA service 0x77fae80015b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754904438.548031     118 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1754904447.718596     118 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1754904528.732107     118 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.1325 - loss: 3.2078
# Epoch 1: val_accuracy improved from -inf to 0.30155, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 467s 636ms/step - accuracy: 0.1327 - loss: 3.2064 - val_accuracy: 0.3015 - val_loss: 2.2387
# Epoch 2/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.4065 - loss: 1.7065
# Epoch 2: val_accuracy improved from 0.30155 to 0.33927, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.4066 - loss: 1.7062 - val_accuracy: 0.3393 - val_loss: 2.5485
# Epoch 3/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5691 - loss: 1.2037
# Epoch 3: val_accuracy improved from 0.33927 to 0.53107, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 259ms/step - accuracy: 0.5691 - loss: 1.2036 - val_accuracy: 0.5311 - val_loss: 1.4021
# Epoch 4/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6693 - loss: 0.9151
# Epoch 4: val_accuracy improved from 0.53107 to 0.66240, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 256ms/step - accuracy: 0.6693 - loss: 0.9151 - val_accuracy: 0.6624 - val_loss: 0.9031
# Epoch 5/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7170 - loss: 0.7623
# Epoch 5: val_accuracy improved from 0.66240 to 0.66876, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.7170 - loss: 0.7623 - val_accuracy: 0.6688 - val_loss: 0.9565
# Epoch 6/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7649 - loss: 0.6589
# Epoch 6: val_accuracy did not improve from 0.66876
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 253ms/step - accuracy: 0.7649 - loss: 0.6589 - val_accuracy: 0.5555 - val_loss: 1.4421
# Epoch 7/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7757 - loss: 0.6131
# Epoch 7: val_accuracy did not improve from 0.66876
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.7757 - loss: 0.6131 - val_accuracy: 0.6223 - val_loss: 1.2011
# Epoch 8/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8133 - loss: 0.5356
# Epoch 8: val_accuracy improved from 0.66876 to 0.68758, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.8133 - loss: 0.5356 - val_accuracy: 0.6876 - val_loss: 0.8966
# Epoch 9/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8296 - loss: 0.4607
# Epoch 9: val_accuracy improved from 0.68758 to 0.77315, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.8296 - loss: 0.4607 - val_accuracy: 0.7731 - val_loss: 0.6278
# Epoch 10/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8469 - loss: 0.4392
# Epoch 10: val_accuracy did not improve from 0.77315
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.8469 - loss: 0.4392 - val_accuracy: 0.6189 - val_loss: 1.3084
# Epoch 11/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8546 - loss: 0.4070
# Epoch 11: val_accuracy did not improve from 0.77315
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.8546 - loss: 0.4070 - val_accuracy: 0.7372 - val_loss: 0.9164
# Epoch 12/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8626 - loss: 0.3742
# Epoch 12: val_accuracy did not improve from 0.77315
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.8626 - loss: 0.3742 - val_accuracy: 0.7685 - val_loss: 0.6844
# Epoch 13/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8785 - loss: 0.3501
# Epoch 13: val_accuracy did not improve from 0.77315
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.8785 - loss: 0.3500 - val_accuracy: 0.7654 - val_loss: 0.7456
# Epoch 14/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8955 - loss: 0.3129
# Epoch 14: val_accuracy improved from 0.77315 to 0.83246, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 118s 264ms/step - accuracy: 0.8955 - loss: 0.3129 - val_accuracy: 0.8325 - val_loss: 0.4889
# Epoch 15/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8868 - loss: 0.3368
# Epoch 15: val_accuracy did not improve from 0.83246
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.8868 - loss: 0.3368 - val_accuracy: 0.7915 - val_loss: 0.6750
# Epoch 16/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8986 - loss: 0.2823
# Epoch 16: val_accuracy did not improve from 0.83246
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.8986 - loss: 0.2823 - val_accuracy: 0.8130 - val_loss: 0.5649
# Epoch 17/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9142 - loss: 0.2497
# Epoch 17: val_accuracy did not improve from 0.83246
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9142 - loss: 0.2497 - val_accuracy: 0.7320 - val_loss: 0.8915
# Epoch 18/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9200 - loss: 0.2489
# Epoch 18: val_accuracy improved from 0.83246 to 0.88197, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9200 - loss: 0.2490 - val_accuracy: 0.8820 - val_loss: 0.3755
# Epoch 19/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9193 - loss: 0.2386
# Epoch 19: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9193 - loss: 0.2386 - val_accuracy: 0.8443 - val_loss: 0.5100
# Epoch 20/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9187 - loss: 0.2388
# Epoch 20: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9186 - loss: 0.2388 - val_accuracy: 0.8516 - val_loss: 0.4597
# Epoch 21/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9288 - loss: 0.2085
# Epoch 21: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 255ms/step - accuracy: 0.9288 - loss: 0.2085 - val_accuracy: 0.8038 - val_loss: 0.6544
# Epoch 22/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9370 - loss: 0.1960
# Epoch 22: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9370 - loss: 0.1960 - val_accuracy: 0.8734 - val_loss: 0.3833
# Epoch 23/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9436 - loss: 0.1694
# Epoch 23: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 248ms/step - accuracy: 0.9436 - loss: 0.1694 - val_accuracy: 0.7799 - val_loss: 0.8101
# Epoch 24/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9405 - loss: 0.1770
# Epoch 24: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9405 - loss: 0.1770 - val_accuracy: 0.8386 - val_loss: 0.5125
# Epoch 25/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9412 - loss: 0.1873
# Epoch 25: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9412 - loss: 0.1872 - val_accuracy: 0.8064 - val_loss: 0.6695
# Epoch 26/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9453 - loss: 0.1639
# Epoch 26: val_accuracy did not improve from 0.88197
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 254ms/step - accuracy: 0.9453 - loss: 0.1639 - val_accuracy: 0.8487 - val_loss: 0.5188
# Epoch 27/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9432 - loss: 0.1751
# Epoch 27: val_accuracy improved from 0.88197 to 0.89812, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 257ms/step - accuracy: 0.9433 - loss: 0.1751 - val_accuracy: 0.8981 - val_loss: 0.3611
# Epoch 28/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9526 - loss: 0.1460
# Epoch 28: val_accuracy did not improve from 0.89812
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 115s 259ms/step - accuracy: 0.9526 - loss: 0.1460 - val_accuracy: 0.8684 - val_loss: 0.4600
# Epoch 29/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9533 - loss: 0.1436
# Epoch 29: val_accuracy did not improve from 0.89812
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9533 - loss: 0.1436 - val_accuracy: 0.8372 - val_loss: 0.5603
# Epoch 30/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9489 - loss: 0.1591
# Epoch 30: val_accuracy improved from 0.89812 to 0.89829, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 255ms/step - accuracy: 0.9489 - loss: 0.1591 - val_accuracy: 0.8983 - val_loss: 0.3409
# Epoch 31/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9597 - loss: 0.1268
# Epoch 31: val_accuracy did not improve from 0.89829
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9596 - loss: 0.1268 - val_accuracy: 0.8804 - val_loss: 0.4054
# Epoch 32/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9528 - loss: 0.1464
# Epoch 32: val_accuracy did not improve from 0.89829
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9528 - loss: 0.1464 - val_accuracy: 0.8410 - val_loss: 0.6029
# Epoch 33/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9543 - loss: 0.1439
# Epoch 33: val_accuracy improved from 0.89829 to 0.91317, saving model to best_densenet_model.h5
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 257ms/step - accuracy: 0.9543 - loss: 0.1439 - val_accuracy: 0.9132 - val_loss: 0.2811
# Epoch 34/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9651 - loss: 0.1104
# Epoch 34: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 249ms/step - accuracy: 0.9651 - loss: 0.1104 - val_accuracy: 0.8858 - val_loss: 0.3837
# Epoch 35/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9673 - loss: 0.1063
# Epoch 35: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9672 - loss: 0.1063 - val_accuracy: 0.8559 - val_loss: 0.5109
# Epoch 36/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9590 - loss: 0.1333
# Epoch 36: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 111s 250ms/step - accuracy: 0.9590 - loss: 0.1333 - val_accuracy: 0.8474 - val_loss: 0.5627
# Epoch 37/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9589 - loss: 0.1250
# Epoch 37: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9589 - loss: 0.1251 - val_accuracy: 0.8848 - val_loss: 0.4012
# Epoch 38/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9676 - loss: 0.1054
# Epoch 38: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 256ms/step - accuracy: 0.9676 - loss: 0.1054 - val_accuracy: 0.9072 - val_loss: 0.3166
# Epoch 39/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9672 - loss: 0.1065
# Epoch 39: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9672 - loss: 0.1065 - val_accuracy: 0.7790 - val_loss: 0.9105
# Epoch 40/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9636 - loss: 0.1206
# Epoch 40: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 113s 253ms/step - accuracy: 0.9636 - loss: 0.1206 - val_accuracy: 0.8925 - val_loss: 0.3979
# Epoch 41/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9657 - loss: 0.1169
# Epoch 41: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 252ms/step - accuracy: 0.9657 - loss: 0.1169 - val_accuracy: 0.8973 - val_loss: 0.3629
# Epoch 42/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9686 - loss: 0.0928
# Epoch 42: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 112s 251ms/step - accuracy: 0.9686 - loss: 0.0928 - val_accuracy: 0.8935 - val_loss: 0.4209
# Epoch 43/50
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9636 - loss: 0.1231
# Epoch 43: val_accuracy did not improve from 0.91317
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 114s 257ms/step - accuracy: 0.9636 - loss: 0.1231 - val_accuracy: 0.9113 - val_loss: 0.3282
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.
# Training completed!
# {"id":"r5MsQr7dYeFO","time":1754909540,"expires":1754952740,"event":"message","topic":"model_complete","message":"Train Complete"}

# %%
test_flow.reset()
y_true = test_flow.classes
y_pred_probs = model.predict(test_flow)
y_pred = np.argmax(y_pred_probs, axis=1)

target_names = list(test_flow.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=target_names, digits=4, output_dict=True)
cm = confusion_matrix(y_true, y_pred)
test_loss, test_acc = model.evaluate(test_flow, verbose=0)

# Precision, Recall, F1 (macro avg)
precision = report["macro avg"]["precision"]
recall = report["macro avg"]["recall"]
f1 = report["macro avg"]["f1-score"]

# GFLOPS & Params
# flops = get_flops(model, batch_size=1)
num_params = model.count_params()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# print(f"GFLOPS: {flops/1e9:.4f}")
print(f"Parameters: {num_params}")

# Confusion Matrix 
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(target_names))
plt.xticks(tick_marks, target_names, rotation=45)
plt.yticks(tick_marks, target_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Loss/Accuracy Curves 
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend(); plt.title("Loss over epochs"); plt.show()
plt.plot(history.history["accuracy"], label="Training Acc")
plt.plot(history.history["val_accuracy"], label="Validation Acc")
plt.legend(); plt.title("Accuracy over epochs"); plt.show()
# Out:
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 130s 314ms/step
# Test Loss: 0.2677
# Test Accuracy: 0.9191
# Precision: 0.8669
# Recall: 0.8865
# F1 Score: 0.8661
# Parameters: 8788843

# %%
model.save('densenet_final_model.keras')
model.save_weights('densenet_final.weights.h5')

# %%
import pandas as pd
results = {
    "Model": ["DenseNet121"],
    "Params": [num_params],
    # "GFLOPS": [f"{flops/1e9:.4f}"],
    "Test Loss": [f"{test_loss:.4f}"],
    "Test Acc": [f"{test_acc:.4f}"],
    "Precision": [f"{precision:.4f}"],
    "Recall": [f"{recall:.4f}"],
    "F1": [f"{f1:.4f}"]
}
df = pd.DataFrame(results)
print(df.to_markdown(index=False))


import random
sample_idx = random.sample(range(test_flow.n), 10)
for idx in sample_idx:
    img_path = test_flow.filepaths[idx]
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    plt.imshow(img)
    true_label = target_names[y_true[idx]]
    pred_label = target_names[y_pred[idx]]
    plt.title(f"True: {true_label} | Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# !curl -d "Finished" ntfy.sh/model_complete
# Out:
# | Model       |   Params |   Test Loss |   Test Acc |   Precision |   Recall |     F1 |
# |:------------|---------:|------------:|-----------:|------------:|---------:|-------:|
# | DenseNet121 |  8788843 |      0.2677 |     0.9191 |      0.8669 |   0.8865 | 0.8661 |
# {"id":"LVOeo7CfzlNt","time":1754909722,"expires":1754952922,"event":"message","topic":"model_complete","message":"Finished"}
